# %%
import pandas as pd

# %%
league_table = pd.read_excel('FootballData.xlsx', 'LeagueTableExport')

# %%
league_table
# Out:
#                        Team  Rank  Points  MP  Win  Draw  Loss  GF  GA  GD  \
# 0                   Arsenal     1      31  12   10     1     1  30  11  19
# 1           Manchester City     2      29  12    9     2     1  37  11  26
# 2         Tottenham Hotspur     3      26  13    8     2     3  26  16  10
# 3          Newcastle United     4      24  13    6     6     1  24  10  14
# 4         Manchester United     5      23  12    7     2     3  17  16   1
# 5                   Chelsea     6      21  12    6     3     3  17  15   2
# 6                    Fulham     7      19  13    5     4     4  22  22   0
# 7    Brighton & Hove Albion     8      18  12    5     3     4  19  15   4
# 8                 Liverpool     9      16  12    4     4     4  23  15   8
# 9            Crystal Palace    10      16  12    4     4     4  13  16  -3
# 10                Brentford    11      15  13    3     6     4  19  22  -3
# ...
