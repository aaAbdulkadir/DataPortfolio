# %% [markdown]
# #                                            Pandas Practice

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Dataset

# %%
dataset = pd.read_csv(r"C:\Users\Abdulkadir\Documents\Programming\Personal\DataScience\pokemon_data.csv")
dataset.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Understanding the dataset

# %%
pd.set_option('display.max_rows', 6)

# %%
len(dataset)
# Out:
# 800

# %%
dataset['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
dataset['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
dataset['HP'].unique()
# Out:
# array([ 45,  60,  80,  39,  58,  78,  44,  59,  79,  50,  40,  65,  63,
#         83,  30,  55,  35,  75,  70,  90,  46,  61,  81,  95,  38,  73,
#        115, 140,  10,  25,  52, 105,  85, 250,  20, 130,  48, 160,  41,
#         91, 106, 100, 125, 190, 255,  28,  68, 150,  31,   1,  64,  84,
#        104,  72, 144, 170, 110,  43,  66,  86,  99,  76,  53,  37,  77,
#         67,  97, 111,  49,  71, 103,  57, 108, 135,  74,  69, 120, 116,
#         62,  54,  36,  51, 114, 165, 109,  89,  92,  56,  88, 123, 101,
#         82,  42, 126], dtype=int64)

# %%
dataset['Generation'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
dataset.loc[4, 'Name']
# Out:
# 'Charmander'

# %% [markdown]
# ### Sorting dataset

# %%
dataset.loc[(dataset['Type 2'] == 'Poison')].head()
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 16  13                 Weedle    Bug  Poison  40      35       30       20
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 16       20     50           1      False

# %%
# lowest attack and highest speed
dataset.sort_values(['Attack', 'Speed'], ascending=[1,0]).head()
# Out:
#        #      Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113   Chansey  Normal    NaN  250       5        5       35      105
# 488  440   Happiny  Normal    NaN  100       5        5       15       65
# 139  129  Magikarp   Water    NaN   20      10       55       15       20
# 261  242   Blissey  Normal    NaN  255      10       10       75      135
# 230  213   Shuckle     Bug   Rock   20      10      230       10      230
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 488     30           4      False
# 139     80           1      False
# 261     55           2      False
# 230      5           2      False

# %%
# create a new column which totals the scores
dataset['Total Scores'] = dataset[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].sum(axis=1)
dataset.sort_values('Total Scores', ascending=False)
modified = dataset.sort_values('Total Scores', ascending=False)
modified
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# ..   ...                    ...      ...       ...  ...     ...      ...
# 446  401              Kricketot      Bug       NaN   37      25       41
# 322  298                Azurill   Normal     Fairy   50      20       40
# 206  191                Sunkern    Grass       NaN   30      30       30
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total Scores
# 426      180      100    115           3       True           780
# 164      194      120    140           1       True           780
# 163      154      100    130           1       True           780
# ..       ...      ...    ...         ...        ...           ...
# ...

# %%
# drop new column
dataset = dataset.drop(columns=['Total Scores'])
dataset
# Out:
#        #                 Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison  45      49       49       65
# 1      2              Ivysaur    Grass  Poison  60      62       63       80
# 2      3             Venusaur    Grass  Poison  80      82       83      100
# ..   ...                  ...      ...     ...  ..     ...      ...      ...
# 797  720  HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799  721            Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# ..       ...    ...         ...        ...
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# ...

# %%
# another way to sum
dataset['Total'] = dataset.iloc[:, 4:10].sum(axis=1)
dataset
# Out:
#        #                 Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison  45      49       49       65
# 1      2              Ivysaur    Grass  Poison  60      62       63       80
# 2      3             Venusaur    Grass  Poison  80      82       83      100
# ..   ...                  ...      ...     ...  ..     ...      ...      ...
# 797  720  HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799  721            Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 0         65     45           1      False    318
# 1         80     60           1      False    405
# 2        100     80           1      False    525
# ..       ...    ...         ...        ...    ...
# 797      130     70           6       True    600
# ...

# %%
cols = list(dataset.columns.values)
cols
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
cols[0:4]
# Out:
# ['#', 'Name', 'Type 1', 'Type 2']

# %%
[cols[-1]]
# Out:
# ['Total']

# %%
dataset = dataset[cols[0:4] + [cols[-1]]]
dataset
# Out:
#        #                 Name   Type 1  Type 2  Total
# 0      1            Bulbasaur    Grass  Poison    318
# 1      2              Ivysaur    Grass  Poison    405
# 2      3             Venusaur    Grass  Poison    525
# ..   ...                  ...      ...     ...    ...
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680
# 799  721            Volcanion     Fire   Water    600
#
# [800 rows x 5 columns]

# %% [markdown]
# ### Clean data

# %%
# reset data
pd.set_option('display.max_rows', 800) # look through all data
dataset = pd.read_csv(r"C:\Users\Abdulkadir\Documents\Programming\Personal\DataScience\pokemon_data.csv")
dataset.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# find NaN in scores
dataset[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']].isnull().values.any()
# Out:
# False

# %%
# no further cleaning required

# %% [markdown]
# ### Filtering data

# %%
df_1 = dataset.loc[(dataset['Defense'] > 50) & (dataset['Speed'] > 50)]
df_1.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 5       65     80           1      False
# 6       85    100           1      False

# %%
df_1 = df_1.reset_index(drop=True) # drop=True drops old index column
df_1.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  2                Ivysaur  Grass  Poison  60      62       63       80
# 1  3               Venusaur  Grass  Poison  80      82       83      100
# 2  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 3  5             Charmeleon   Fire     NaN  58      64       58       80
# 4  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 0       80     60           1      False
# 1      100     80           1      False
# 2      120     80           1      False
# 3       65     80           1      False
# 4       85    100           1      False

# %%
df_3 = dataset.query("Defense>50 and Speed>50")
df_3.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 5       65     80           1      False
# 6       85    100           1      False

# %%
# starts with particular letter
df_2 = dataset[dataset['Name'].str.startswith('V')]
df_2.head()
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 42  37                 Vulpix   Fire     NaN  38      41       40       50
# 50  45              Vileplume  Grass  Poison  75      80       85      110
# 53  48                Venonat    Bug  Poison  60      55       50       40
#
#     Sp. Def  Speed  Generation  Legendary
# 2       100     80           1      False
# 3       120     80           1      False
# 42       65     65           1      False
# 50       90     50           1      False
# 53       55     45           1      False

# %%
df_4 = dataset[dataset['Name'].str.contains('Char')]
df_4
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
# drop the ones you located
df_5 = dataset[~dataset['Name'].str.contains('Char')]
df_5.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 9  7               Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 9       64     43           1      False

# %%
# verify it is gone
df_5[df_5['Name'].str.contains('Char')]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
import re

dataset[dataset['Name'].str.contains('^Ven[a-z]*', flags=re.I, regex=True)] # ^ means starts with ans * means any character after
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 53    48                Venonat    Bug  Poison  60      55       50       40
# 54    49               Venomoth    Bug  Poison  70      65       60       90
# 603  543               Venipede    Bug  Poison  30      45       59       30
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 53        55     45           1      False
# 54        75     90           1      False
# 603       39     57           5      False

# %% [markdown]
# ### Conditional changes

# %%
# change 'grass' in type 1 with 'flamethrower'
dataset['Type 1'] = dataset['Type 1'].replace({'Grass': 'Flamethrower'})
dataset.head()
# Out:
#    #                   Name        Type 1  Type 2  HP  Attack  Defense  \
# 0  1              Bulbasaur  Flamethrower  Poison  45      49       49
# 1  2                Ivysaur  Flamethrower  Poison  60      62       63
# 2  3               Venusaur  Flamethrower  Poison  80      82       83
# 3  3  VenusaurMega Venusaur  Flamethrower  Poison  80     100      123
# 4  4             Charmander          Fire     NaN  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# change all 'flamethrower' type to a legendary type of true
dataset.loc[dataset['Type 1'] == 'Flamethrower', 'Legendary'] = True
dataset.head()
# Out:
#    #                   Name        Type 1  Type 2  HP  Attack  Defense  \
# 0  1              Bulbasaur  Flamethrower  Poison  45      49       49
# 1  2                Ivysaur  Flamethrower  Poison  60      62       63
# 2  3               Venusaur  Flamethrower  Poison  80      82       83
# 3  3  VenusaurMega Venusaur  Flamethrower  Poison  80     100      123
# 4  4             Charmander          Fire     NaN  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1       True
# 1       80       80     60           1       True
# 2      100      100     80           1       True
# 3      122      120     80           1       True
# 4       60       50     65           1      False

# %%
# reset data
dataset = pd.read_csv(r"C:\Users\Abdulkadir\Documents\Programming\Personal\DataScience\pokemon_data.csv")
dataset.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
modified.head()
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary  Total Scores
# 426      180      100    115        100     Ultra           780
# 164      194      120    140        100     Ultra           780
# 163      154      100    130        100     Ultra           780
# 422      180      160     90        100     Ultra           770
# 424      150       90     90        100     Ultra           770

# %%
modified.loc[modified['Total Scores'] > 700, ['Generation', 'Legendary']] = ['100', 'Ultra']
legendary_modified = modified.loc[modified['Generation'] == '100']
legendary_modified
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# 552  493                 Arceus   Normal       NaN  120     120      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary  Total Scores
# 426      180      100    115        100     Ultra           780
# 164      194      120    140        100     Ultra           780
# 163      154      100    130        100     Ultra           780
# 422      180      160     90        100     Ultra           770
# 424      150       90     90        100     Ultra           770
# 552      120      120    120        100     Ultra           720

# %% [markdown]
# ### Aggregate stats

# %%
# reset data
dataset = pd.read_csv(r"C:\Users\Abdulkadir\Documents\Programming\Personal\DataScience\pokemon_data.csv")
dataset.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
grouped = dataset.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
grouped
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# ...

# %%
# count
count = dataset.groupby(['Type 1']).count()
count[['#']]
# Out:
#             #
# Type 1
# Bug        69
# Dark       31
# Dragon     32
# Electric   44
# Fairy      17
# Fighting   27
# Fire       52
# Flying      4
# Ghost      32
# Grass      70
# Ground     32
# Ice        24
# Normal     98
# Poison     28
# Psychic    57
# Rock       44
# Steel      27
# Water     112

# %% [markdown]
# ### Pivot tables

# %%
pivot = dataset.groupby('Type 2')[['Attack']].mean()
pivot
# Out:
#               Attack
# Type 2
# Bug        90.000000
# Dark      109.800000
# Dragon     94.444444
# Electric   72.666667
# Fairy      61.608696
# Fighting  112.846154
# Fire       81.250000
# Flying     80.288660
# Ghost      84.142857
# Grass      74.160000
# Ground     89.857143
# Ice        98.000000
# Normal     52.750000
# Poison     67.588235
# Psychic    74.696970
# Rock       84.000000
# Steel      92.590909
# Water      70.142857

# %%
pivot_2 = dataset.pivot_table('Attack', index='Type 2', columns='Generation') # gives mean attack
pivot_2
# Out:
# Generation           1           2           3           4           5  \
# Type 2
# Bug                NaN         NaN  110.000000   50.000000         NaN
# Dark        155.000000  149.000000  107.857143   84.500000   90.333333
# Dragon      130.000000   95.000000   93.333333  115.000000   85.000000
# Electric           NaN   48.000000         NaN         NaN   85.000000
# Fairy        53.333333   33.333333   66.250000   25.000000   51.333333
# Fighting    142.500000  155.000000  123.750000  110.714286   96.200000
# Fire               NaN   80.000000  180.000000   65.000000   70.000000
# Flying       90.086957   60.263158   87.714286   73.937500   88.473684
# Ghost              NaN         NaN   83.333333   65.000000   74.500000
# Grass        82.500000  100.000000   54.400000   62.000000   75.800000
# Ground       89.000000   79.750000   88.444444  107.625000   80.000000
# Ice          83.333333   95.000000         NaN   94.200000  140.000000
# ...

# %%
dataset[(dataset['Type 2'] == 'Bug') & (dataset['Generation'] == 3)]
# Out:
#        #     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 379  347  Anorith   Rock    Bug  45      95       50       40       50     75
# 380  348  Armaldo   Rock    Bug  75     125      100       70       80     45
#
#      Generation  Legendary
# 379           3      False
# 380           3      False

# %%
pivot_3 = dataset.pivot_table(index='Type 2', columns='Legendary', aggfunc={'Attack':'mean', 'Defense':'mean'})
pivot_3
# Out:
#                Attack                 Defense
# Legendary       False       True        False       True
# Type 2
# Bug         90.000000         NaN   80.000000         NaN
# Dark       107.157895  160.000000   72.684211   60.000000
# Dragon      88.571429  115.000000   80.500000  110.000000
# Electric    57.200000  150.000000   58.000000  120.000000
# Fairy       55.095238  130.000000   68.523810  130.000000
# Fighting   110.681818  124.750000   79.727273   97.750000
# Fire        63.888889  133.333333   66.888889  120.000000
# Flying      74.273810  119.153846   64.892857   90.384615
# Ghost       82.153846  110.000000   84.000000   60.000000
# Grass       74.160000         NaN   80.120000         NaN
# Ground      89.558824  100.000000   89.411765  121.000000
# Ice         86.545455  140.000000   83.545455   93.333333
# Normal      52.750000         NaN   53.750000         NaN
# Poison      67.588235         NaN   59.558824         NaN
# ...

# %%
pivot_3.head(2)
# Out:
#                Attack           Defense
# Legendary       False  True       False True
# Type 2
# Bug         90.000000    NaN  80.000000   NaN
# Dark       107.157895  160.0  72.684211  60.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set() # use seaborn styles
pivot_3.head(3).plot()
# Out:
# <AxesSubplot:xlabel='Type 2'>

# %%
# do a count: another way
dataset['count'] = 0
dataset

count = dataset.groupby(['Type 1']).count()
count[['count']]
# Out:
#           count
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112

# %%
count_2 = dataset.groupby(['Type 1', 'Type 2']).count()
count_2[['count']]
# Out:
#                    count
# Type 1   Type 2
# Bug      Electric      2
#          Fighting      2
#          Fire          2
#          Flying       14
#          Ghost         1
#          Grass         6
#          Ground        2
#          Poison       12
#          Rock          3
#          Steel         7
#          Water         1
# Dark     Dragon        3
#          Fighting      2
#          Fire          3
#          Flying        5
#          Ghost         2
#          Ice           2
#          Psychic       2
#          Steel         2
# Dragon   Electric      1
#          Fairy         1
#          Fire          1
#          Flying        6
#          Ground        5
#          Ice           3
#          Psychic       4
# Electric Dragon        1
#          Fairy         1
#          Fire          1
#          Flying        5
#          Ghost         1
#          Grass         1
#          Ice           1
#          Normal        2
#          Steel         3
# ...

# %% [markdown]
# ### Working with large datasets and reading in chunks

# %%
for df in pd.read_csv(r"C:\Users\Abdulkadir\Documents\Programming\Personal\DataScience\pokemon_data.csv", chunksize=10):
    print(f'Chunk')
    print(df.head(5))
# Out:
# Chunk
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# Chunk
#      #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 10   8                Wartortle  Water    NaN  59      63       80       65
# 11   9                Blastoise  Water    NaN  79      83      100       85
# ...

# %%
# empty df with columns from chunks size df
new_df = pd.DataFrame(columns=df.columns)
new_df
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
for df in pd.read_csv(r"C:\Users\Abdulkadir\Documents\Programming\Personal\DataScience\pokemon_data.csv", chunksize=10):
    results = df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])

new_df[['#']]
# Out:
#          #
# Fire     5
# Grass    4
# Water    1
# Bug      7
# Water    3
# ...     ..
# Fairy    1
# Fire     1
# Flying   2
# Psychic  2
# Rock     2
#
# [1083 rows x 1 columns]
