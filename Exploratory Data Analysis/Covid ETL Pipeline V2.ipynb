# %% [markdown]
# # COVID Data ETL Pipeline for BI

# %% [markdown]
# This project consists of creating an ETL pipeline whereby I collect COVID data from the World Data website, use that data to find useful analytical insights that could be displayed on PowerBI for BI reporting. The dashboard is intended to update everyday with new data by automating the processing and connecting each stage such that the data reflected on the dashboard is relevant. This script will achieve that goal and will be ran daily using windows task scheduler for simplicity.

# %% [markdown]
# **Table of Contents:**
# 1. Extract Data
# 2. Data Exploration and Cleansing (Transform)
# 3. Exploratory Data Analysis
# 4. Export Data

# %%
'''Data Analytics'''
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

import geopandas
from mpl_toolkits.axes_grid1 import make_axes_locatable # for geopandas aligning of legend and graph
import datetime

'''Webscraping'''
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC, wait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support.ui import WebDriverWait
import time
import os # delete files off computer
import sys # exit

'''Connect to SQL'''
import pyodbc # sql
from sqlalchemy import create_engine # sql to insert df to sql
import urllib # for sql too

# %% [markdown]
# ## 1. Extract Data

# %%
# open covid data website
path = r"C:\Users\Abdulkadir\Documents\Programming\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get('https://ourworldindata.org/covid-deaths')
wait = WebDriverWait(driver, 5)

# download csv file
try:
    csvLink = wait.until(EC.presence_of_element_located((By.XPATH, "/html/body/main/article/div[3]/div[2]/div/div/section[1]/div/div[1]/div[1]/div/div/a[2]")))
    csvLink.click()
except:
    print('Download failed')
    sys.exit()

    
# file path of csv
filepath = r"C:\Users\Abdulkadir\Downloads\owid-covid-data.csv"


# load csv file into df
x = 1
while True:
    try:
        csv = pd.read_csv(filepath)
        print('CSV succesfully downloaded.')
        break
    except:
        print(f'CSV downloading... {x}/100.')
        x += 1
        time.sleep(3)
    
    if x == 30:
        print('CSV Failed')
        #sys.exit()

# close driver
driver.close()
        
# delete the csv file off my computer so it does not interfere with downlaoding new data and names
try:
    os.remove(filepath)
    print('CSV successfully deleted.')
except:
    print('CSV does not exist.')
# Out:
# CSV downloading... 1/100.
# CSV downloading... 2/100.
# CSV downloading... 3/100.
# CSV downloading... 4/100.
# CSV downloading... 5/100.
# CSV downloading... 6/100.
# CSV downloading... 7/100.
# CSV downloading... 8/100.
# CSV succesfully downloaded.
# CSV successfully deleted.

# %% [markdown]
# ## 2. Data Exploration and Cleansing (Transform)

# %%
df = csv.copy()

# %%
# see all columns
pd.set_option('display.max_columns', 500)

# %%
df.shape
# Out:
# (207316, 67)

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 207311      ZWE    Africa  Zimbabwe  2022-08-04     256444.0       21.0
# 207312      ZWE    Africa  Zimbabwe  2022-08-05     256444.0        0.0
# 207313      ZWE    Africa  Zimbabwe  2022-08-06     256444.0        0.0
# 207314      ZWE    Africa  Zimbabwe  2022-08-07     256447.0        3.0
# 207315      ZWE    Africa  Zimbabwe  2022-08-08     256487.0       40.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 207311              15.429        5581.0         2.0                0.714
# 207312               9.714        5581.0         0.0                0.571
# 207313               9.714        5581.0         0.0                0.571
# 207314               9.857        5584.0         3.0                1.000
# 207315              15.000        5584.0         0.0                1.000
#
#         total_cases_per_million  new_cases_per_million  \
# 207311                16034.240                  1.313
# 207312                16034.240                  0.000
# 207313                16034.240                  0.000
# 207314                16034.427                  0.188
# 207315                16036.928                  2.501
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 207311                           0.965                   348.954
# 207312                           0.607                   348.954
# 207313                           0.607                   348.954
# 207314                           0.616                   349.141
# 207315                           0.938                   349.141
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 207311                   0.125                            0.045
# 207312                   0.000                            0.036
# 207313                   0.000                            0.036
# 207314                   0.188                            0.063
# 207315                   0.000                            0.063
#
#         reproduction_rate  icu_patients  icu_patients_per_million  \
# 207311               0.82           NaN                       NaN
# 207312                NaN           NaN                       NaN
# 207313                NaN           NaN                       NaN
# 207314                NaN           NaN                       NaN
# 207315                NaN           NaN                       NaN
#
#         hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 207311            NaN                        NaN                    NaN
# 207312            NaN                        NaN                    NaN
# 207313            NaN                        NaN                    NaN
# 207314            NaN                        NaN                    NaN
# 207315            NaN                        NaN                    NaN
#
#         weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 207311                                NaN                     NaN
# 207312                                NaN                     NaN
# 207313                                NaN                     NaN
# 207314                                NaN                     NaN
# 207315                                NaN                     NaN
#
#         weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 207311                                 NaN          NaN        NaN
# 207312                                 NaN          NaN        NaN
# 207313                                 NaN          NaN        NaN
# 207314                                 NaN          NaN        NaN
# 207315                                 NaN          NaN        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 207311                       NaN                     NaN                 NaN
# 207312                       NaN                     NaN                 NaN
# 207313                       NaN                     NaN                 NaN
# 207314                       NaN                     NaN                 NaN
# 207315                       NaN                     NaN                 NaN
#
#         new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 207311                              NaN            NaN             NaN
# 207312                              NaN            NaN             NaN
# 207313                              NaN            NaN             NaN
# 207314                              NaN            NaN             NaN
# 207315                              NaN            NaN             NaN
#
#        tests_units  total_vaccinations  people_vaccinated  \
# 207311         NaN                 NaN                NaN
# 207312         NaN                 NaN                NaN
# 207313         NaN                 NaN                NaN
# 207314         NaN                 NaN                NaN
# 207315         NaN                 NaN                NaN
#
#         people_fully_vaccinated  total_boosters  new_vaccinations  \
# 207311                      NaN             NaN               NaN
# 207312                      NaN             NaN               NaN
# 207313                      NaN             NaN               NaN
# 207314                      NaN             NaN               NaN
# 207315                      NaN             NaN               NaN
#
#         new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 207311                        NaN                             NaN
# 207312                        NaN                             NaN
# 207313                        NaN                             NaN
# 207314                        NaN                             NaN
# 207315                        NaN                             NaN
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 207311                            NaN                                  NaN
# 207312                            NaN                                  NaN
# 207313                            NaN                                  NaN
# 207314                            NaN                                  NaN
# 207315                            NaN                                  NaN
#
#         total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 207311                         NaN                                    NaN
# 207312                         NaN                                    NaN
# 207313                         NaN                                    NaN
# 207314                         NaN                                    NaN
# 207315                         NaN                                    NaN
#
#         new_people_vaccinated_smoothed  \
# 207311                             NaN
# 207312                             NaN
# 207313                             NaN
# 207314                             NaN
# 207315                             NaN
#
#         new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 207311                                         NaN               NaN
# 207312                                         NaN               NaN
# 207313                                         NaN               NaN
# 207314                                         NaN               NaN
# 207315                                         NaN               NaN
#
#         population  population_density  median_age  aged_65_older  \
# 207311  15993524.0              42.729        19.6          2.822
# 207312  15993524.0              42.729        19.6          2.822
# 207313  15993524.0              42.729        19.6          2.822
# 207314  15993524.0              42.729        19.6          2.822
# 207315  15993524.0              42.729        19.6          2.822
#
#         aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 207311          1.882        1899.775             21.4                307.846
# 207312          1.882        1899.775             21.4                307.846
# 207313          1.882        1899.775             21.4                307.846
# 207314          1.882        1899.775             21.4                307.846
# 207315          1.882        1899.775             21.4                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 207311                 1.82             1.6          30.7
# 207312                 1.82             1.6          30.7
# 207313                 1.82             1.6          30.7
# 207314                 1.82             1.6          30.7
# 207315                 1.82             1.6          30.7
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 207311                  36.791                         1.7            61.49
# 207312                  36.791                         1.7            61.49
# 207313                  36.791                         1.7            61.49
# 207314                  36.791                         1.7            61.49
# 207315                  36.791                         1.7            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 207311                    0.571                                   NaN
# 207312                    0.571                                   NaN
# 207313                    0.571                                   NaN
# 207314                    0.571                                   NaN
# 207315                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 207311                          NaN               NaN
# 207312                          NaN               NaN
# 207313                          NaN               NaN
# 207314                          NaN               NaN
# 207315                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 207311                                      NaN
# 207312                                      NaN
# 207313                                      NaN
# 207314                                      NaN
# 207315                                      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207316 entries, 0 to 207315
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    207316 non-null  object
#  1   continent                                   195332 non-null  object
#  2   location                                    207316 non-null  object
#  3   date                                        207316 non-null  object
#  4   total_cases                                 198929 non-null  float64
#  5   new_cases                                   198644 non-null  float64
#  6   new_cases_smoothed                          197467 non-null  float64
#  7   total_deaths                                180147 non-null  float64
#  8   new_deaths                                  180104 non-null  float64
#  9   new_deaths_smoothed                         178937 non-null  float64
#  10  total_cases_per_million                     198015 non-null  float64
#  11  new_cases_per_million                       197730 non-null  float64
#  12  new_cases_smoothed_per_million              196558 non-null  float64
#  13  total_deaths_per_million                    179246 non-null  float64
#  14  new_deaths_per_million                      179203 non-null  float64
#  15  new_deaths_smoothed_per_million             178041 non-null  float64
#  16  reproduction_rate                           155412 non-null  float64
#  17  icu_patients                                27379 non-null   float64
#  18  icu_patients_per_million                    27379 non-null   float64
#  19  hosp_patients                               29297 non-null   float64
#  20  hosp_patients_per_million                   29297 non-null   float64
#  21  weekly_icu_admissions                       6790 non-null    float64
#  22  weekly_icu_admissions_per_million           6790 non-null    float64
#  23  weekly_hosp_admissions                      13465 non-null   float64
#  24  weekly_hosp_admissions_per_million          13465 non-null   float64
#  25  total_tests                                 79385 non-null   float64
#  26  new_tests                                   75401 non-null   float64
#  27  total_tests_per_thousand                    79385 non-null   float64
#  28  new_tests_per_thousand                      75401 non-null   float64
#  29  new_tests_smoothed                          103963 non-null  float64
#  30  new_tests_smoothed_per_thousand             103963 non-null  float64
#  31  positive_rate                               95920 non-null   float64
#  32  tests_per_case                              94058 non-null   float64
#  33  tests_units                                 106786 non-null  object
#  34  total_vaccinations                          57906 non-null   float64
#  35  people_vaccinated                           55259 non-null   float64
#  36  people_fully_vaccinated                     52571 non-null   float64
#  37  total_boosters                              29504 non-null   float64
#  38  new_vaccinations                            47635 non-null   float64
#  39  new_vaccinations_smoothed                   116360 non-null  float64
#  40  total_vaccinations_per_hundred              57906 non-null   float64
#  41  people_vaccinated_per_hundred               55259 non-null   float64
#  42  people_fully_vaccinated_per_hundred         52571 non-null   float64
#  43  total_boosters_per_hundred                  29504 non-null   float64
#  44  new_vaccinations_smoothed_per_million       116360 non-null  float64
#  45  new_people_vaccinated_smoothed              115458 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  115458 non-null  float64
#  47  stringency_index                            155352 non-null  float64
#  48  population                                  206085 non-null  float64
#  49  population_density                          184476 non-null  float64
#  50  median_age                                  170940 non-null  float64
#  51  aged_65_older                               169133 non-null  float64
#  52  aged_70_older                               170045 non-null  float64
#  53  gdp_per_capita                              169951 non-null  float64
#  54  extreme_poverty                             110856 non-null  float64
#  55  cardiovasc_death_rate                       170514 non-null  float64
#  56  diabetes_prevalence                         178974 non-null  float64
#  57  female_smokers                              128976 non-null  float64
#  58  male_smokers                                127209 non-null  float64
#  59  handwashing_facilities                      83747 non-null   float64
#  60  hospital_beds_per_thousand                  151513 non-null  float64
#  61  life_expectancy                             193942 non-null  float64
#  62  human_development_index                     166076 non-null  float64
#  63  excess_mortality_cumulative_absolute        7021 non-null    float64
#  64  excess_mortality_cumulative                 7021 non-null    float64
#  65  excess_mortality                            7039 non-null    float64
#  66  excess_mortality_cumulative_per_million     7021 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 106.0+ MB

# %%
for col_name in df.columns:
    print(f'{col_name}: {df[col_name].isnull().sum()}')
# Out:
# iso_code: 0
# continent: 11984
# location: 0
# date: 0
# total_cases: 8387
# new_cases: 8672
# new_cases_smoothed: 9849
# total_deaths: 27169
# new_deaths: 27212
# new_deaths_smoothed: 28379
# total_cases_per_million: 9301
# new_cases_per_million: 9586
# new_cases_smoothed_per_million: 10758
# total_deaths_per_million: 28070
# new_deaths_per_million: 28113
# new_deaths_smoothed_per_million: 29275
# reproduction_rate: 51904
# icu_patients: 179937
# icu_patients_per_million: 179937
# hosp_patients: 178019
# hosp_patients_per_million: 178019
# weekly_icu_admissions: 200526
# weekly_icu_admissions_per_million: 200526
# weekly_hosp_admissions: 193851
# weekly_hosp_admissions_per_million: 193851
# total_tests: 127931
# new_tests: 131915
# total_tests_per_thousand: 127931
# new_tests_per_thousand: 131915
# new_tests_smoothed: 103353
# new_tests_smoothed_per_thousand: 103353
# positive_rate: 111396
# tests_per_case: 113258
# tests_units: 100530
# total_vaccinations: 149410
# people_vaccinated: 152057
# people_fully_vaccinated: 154745
# total_boosters: 177812
# new_vaccinations: 159681
# new_vaccinations_smoothed: 90956
# total_vaccinations_per_hundred: 149410
# people_vaccinated_per_hundred: 152057
# people_fully_vaccinated_per_hundred: 154745
# total_boosters_per_hundred: 177812
# new_vaccinations_smoothed_per_million: 90956
# new_people_vaccinated_smoothed: 91858
# new_people_vaccinated_smoothed_per_hundred: 91858
# stringency_index: 51964
# population: 1231
# population_density: 22840
# median_age: 36376
# aged_65_older: 38183
# aged_70_older: 37271
# gdp_per_capita: 37365
# extreme_poverty: 96460
# cardiovasc_death_rate: 36802
# diabetes_prevalence: 28342
# female_smokers: 78340
# male_smokers: 80107
# handwashing_facilities: 123569
# hospital_beds_per_thousand: 55803
# life_expectancy: 13374
# human_development_index: 41240
# excess_mortality_cumulative_absolute: 200295
# excess_mortality_cumulative: 200295
# excess_mortality: 200277
# excess_mortality_cumulative_per_million: 200295

# %% [markdown]
# ### 2.1 Understanding the data

# %%
np.unique(df['iso_code'])
# Out:
# array(['ABW', 'AFG', 'AGO', 'AIA', 'ALB', 'AND', 'ARE', 'ARG', 'ARM',
#        'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BES', 'BFA',
#        'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL',
#        'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COK', 'COL', 'COM', 'CPV',
#        'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA',
#        'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESH', 'ESP', 'EST',
#        'ETH', 'FIN', 'FJI', 'FLK', 'FRA', 'FRO', 'FSM', 'GAB', 'GBR',
#        'GEO', 'GGY', 'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC',
#        'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HKG', 'HND', 'HRV', 'HTI',
#        'HUN', 'IDN', 'IMN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR',
#        'ITA', 'JAM', 'JEY', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM',
#        'KIR', 'KNA', 'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA',
#        'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAC', 'MAR', 'MCO',
#        'MDA', 'MDG', 'MDV', 'MEX', 'MHL', 'MKD', 'MLI', 'MLT', 'MMR',
#        'MNE', 'MNG', 'MNP', 'MOZ', 'MRT', 'MSR', 'MUS', 'MWI', 'MYS',
#        'NAM', 'NCL', 'NER', 'NGA', 'NIC', 'NIU', 'NLD', 'NOR', 'NPL',
#        'NRU', 'NZL', 'OMN', 'OWID_AFR', 'OWID_ASI', 'OWID_CYN',
#        'OWID_EUN', 'OWID_EUR', 'OWID_HIC', 'OWID_INT', 'OWID_KOS',
#        'OWID_LIC', 'OWID_LMC', 'OWID_NAM', 'OWID_OCE', 'OWID_SAM',
#        'OWID_UMC', 'OWID_WRL', 'PAK', 'PAN', 'PCN', 'PER', 'PHL', 'PLW',
#        'PNG', 'POL', 'PRI', 'PRK', 'PRT', 'PRY', 'PSE', 'PYF', 'QAT',
#        'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SHN', 'SLB',
#        'SLE', 'SLV', 'SMR', 'SOM', 'SPM', 'SRB', 'SSD', 'STP', 'SUR',
#        'SVK', 'SVN', 'SWE', 'SWZ', 'SXM', 'SYC', 'SYR', 'TCA', 'TCD',
#        'TGO', 'THA', 'TJK', 'TKL', 'TKM', 'TLS', 'TON', 'TTO', 'TUN',
#        'TUR', 'TUV', 'TWN', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB',
#        'VAT', 'VCT', 'VEN', 'VGB', 'VIR', 'VNM', 'VUT', 'WLF', 'WSM',
#        'YEM', 'ZAF', 'ZMB', 'ZWE'], dtype=object)

# %% [markdown]
# Explore OWID codes

# %%
explore_code = ['OWID_AFR', 'OWID_ASI', 'OWID_CYN',
       'OWID_EUN', 'OWID_EUR', 'OWID_HIC', 'OWID_INT', 'OWID_KOS',
       'OWID_LIC', 'OWID_LMC', 'OWID_NAM', 'OWID_OCE', 'OWID_SAM',
       'OWID_UMC', 'OWID_WRL']

# %%
df.loc[df['iso_code'].isin(explore_code)].groupby(['iso_code', 'location']).agg({'population':'max'})
# Out:
#                                 population
# iso_code location
# OWID_AFR Africa               1.392394e+09
# OWID_ASI Asia                 4.693235e+09
# OWID_CYN Northern Cyprus               NaN
# OWID_EUN European Union       4.475935e+08
# OWID_EUR Europe               7.486552e+08
# OWID_HIC High income          1.241374e+09
# OWID_INT International                 NaN
# OWID_KOS Kosovo               1.782115e+06
# OWID_LIC Low income           7.019270e+08
# OWID_LMC Lower middle income  3.363197e+09
# OWID_NAM North America        5.963153e+08
# OWID_OCE Oceania              4.449177e+07
# OWID_SAM South America        4.339567e+08
# OWID_UMC Upper middle income  2.501428e+09
# OWID_WRL World                7.909295e+09

# %% [markdown]
# **Note:**
# - OWID_AFR == Africa
# - OWID_ASI == Asia
# - OWID_NAM == North America
# - OWID_OCE == Oceania
# - OWID_SAM == South America
# - OWID_EUR == Europe
# ---
# - OWID_EUN == European Union
# - OWID_HIC == High income
# - OWID_LIC == Low income
# - OWID_LMC == Lower middle income
# - OWID_UMC == upper middle income
# ---
# - OWID_INT == International
# - OWID_WRL == World

# %% [markdown]
# Additionally, if NaN, it most likely means it was 0 at the time. Therefore fillna(0)

# %%
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
#                                           ..
# human_development_index                    0
# excess_mortality_cumulative_absolute       0
# excess_mortality_cumulative                0
# excess_mortality                           0
# excess_mortality_cumulative_per_million    0
# Length: 67, dtype: int64

# %% [markdown]
# Taking features of interest:

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %% [markdown]
# - Remove columns with: _per _, _smoothed
# - Keep hospital_beds_per_thousand

# %% [markdown]
# Reduce columns to use:

# %%
features_to_keep = []
key_words_to_drop = "_per_|_smoothed"

# %%
import re

def remove(word):
    for col_name in df.columns:
        if re.search(word, col_name):
            pass
        else:
            features_to_keep.append(col_name)

# %%
remove(key_words_to_drop)

# %%
features_to_keep.append('hospital_beds_per_thousand')

# %%
print(features_to_keep)
# Out:
# ['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'reproduction_rate', 'icu_patients', 'hosp_patients', 'weekly_icu_admissions', 'weekly_hosp_admissions', 'total_tests', 'new_tests', 'positive_rate', 'tests_units', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'total_boosters', 'new_vaccinations', 'stringency_index', 'population', 'population_density', 'median_age', 'aged_65_older', 'aged_70_older', 'extreme_poverty', 'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers', 'male_smokers', 'handwashing_facilities', 'life_expectancy', 'human_development_index', 'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative', 'excess_mortality', 'hospital_beds_per_thousand']

# %% [markdown]
# Add month and year column

# %%
from datetime import datetime

df['date'] = pd.to_datetime(df['date'])

# %%
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df['day'] = df['date'].dt.day

# %%
df_small = df[features_to_keep]

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %%
df.shape
# Out:
# (207316, 70)

# %%
# rid scientific notation
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df_small.describe()
# Out:
#           total_cases     new_cases  total_deaths   new_deaths  \
# count    207316.00000  207316.00000  207316.00000 207316.00000
# mean    3679214.34307   12053.77460   60110.75734    128.49108
# std    23587963.43858   85455.24859  334888.39900    710.34845
# min           0.00000       0.00000       0.00000      0.00000
# 25%        2173.00000       0.00000      27.00000      0.00000
# 50%       34611.50000      49.00000     538.00000      0.00000
# 75%      401121.00000     907.00000    6632.25000     11.00000
# max   585413970.00000 4079467.00000 6420297.00000  18191.00000
#
#        reproduction_rate  icu_patients  hosp_patients  weekly_icu_admissions  \
# count       207316.00000  207316.00000   207316.00000           207316.00000
# mean             0.72327     113.40432      595.31938               14.39104
# std              0.53080     954.01910     4378.02958              133.02443
# min             -0.10000       0.00000        0.00000                0.00000
# 25%              0.00000       0.00000        0.00000                0.00000
# 50%              0.85000       0.00000        0.00000                0.00000
# 75%              1.09000       0.00000        0.00000                0.00000
# max              6.15000   28891.00000   154513.00000             4838.00000
#
#        weekly_hosp_admissions      total_tests      new_tests  positive_rate  \
# count            207316.00000     207316.00000   207316.00000   207316.00000
# mean                366.21799    8077119.15770    24471.21343        0.04521
# std                3738.14373   53005352.23965   152869.24506        0.09224
# min                   0.00000          0.00000        0.00000        0.00000
# 25%                   0.00000          0.00000        0.00000        0.00000
# 50%                   0.00000          0.00000        0.00000        0.00000
# 75%                   0.00000     789759.00000     3207.00000        0.04700
# max              153988.00000 9214000000.00000 35855632.00000        1.00000
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        207316.00000       207316.00000             207316.00000
# mean       71815256.37790     32392060.74599           26314755.51463
# std       581145182.00741    267888822.14448          230168133.95528
# min               0.00000            0.00000                  0.00000
# 25%               0.00000            0.00000                  0.00000
# 50%               0.00000            0.00000                  0.00000
# 75%          125584.75000        37184.00000                858.00000
# max     12409986943.00000   5312088076.00000         4882574379.00000
#
#         total_boosters  new_vaccinations  stringency_index       population  \
# count     207316.00000      207316.00000      207316.00000     207316.00000
# mean     6922480.91347      232695.32987          37.62567  142353716.92236
# std     78540635.11842     1883710.24686          28.74260  694120874.14444
# min            0.00000           0.00000           0.00000          0.00000
# 25%            0.00000           0.00000           0.00000     821626.00000
# 50%            0.00000           0.00000          40.74000    7425058.00000
# 75%            0.00000           0.00000          60.33000   32981641.00000
# max   2303919896.00000    49672398.00000         100.00000 7909295152.00000
#
#        population_density   median_age  aged_65_older  aged_70_older  \
# count        207316.00000 207316.00000   207316.00000   207316.00000
# mean            406.95098     25.26341        7.19595        4.56378
# std            1994.59454     14.26798        6.50809        4.33478
# min               0.00000      0.00000        0.00000        0.00000
# 25%              21.18800     18.60000        2.58100        1.52500
# 50%              77.39000     27.60000        4.80000        2.89100
# 75%             207.97300     37.40000       11.23200        7.04900
# max           20546.76600     48.20000       27.04900       18.49300
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# count     207316.00000           207316.00000         207316.00000
# mean           7.28755              214.64459              7.22206
# std           16.15092              147.55684              5.22334
# min            0.00000                0.00000              0.00000
# 25%            0.00000              114.31600              3.94000
# 50%            0.20000              217.06600              6.82000
# 75%            3.40000              304.19500             10.08000
# max           77.60000              724.41700             30.53000
#
#        female_smokers  male_smokers  handwashing_facilities  life_expectancy  \
# count    207316.00000  207316.00000            207316.00000     207316.00000
# mean          6.63151      20.12666                20.55136         68.89412
# std           9.83210      19.16943                32.13871         19.47348
# min           0.00000       0.00000                 0.00000          0.00000
# 25%           0.00000       0.00000                 0.00000         66.70000
# 50%           1.60000      19.10000                 0.00000         74.47000
# 75%           8.80000      35.60000                36.79100         78.88000
# max          44.00000      78.10000               100.00000         86.75000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count             207316.00000                          207316.00000
# mean                   0.58078                            1504.97149
# std                    0.31892                           24163.53312
# min                    0.00000                          -37726.10000
# 25%                    0.48000                               0.00000
# 50%                    0.70400                               0.00000
# 75%                    0.81400                               0.00000
# max                    0.95700                         1219077.90000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                 207316.00000      207316.00000
# mean                       0.32589           0.50000
# std                        3.07443           5.65791
# min                      -28.45000         -95.92000
# 25%                        0.00000           0.00000
# 50%                        0.00000           0.00000
# 75%                        0.00000           0.00000
# max                       76.55000         375.98000
#
#        hospital_beds_per_thousand
# count                207316.00000
# mean                      2.25454
# std                       2.57452
# min                       0.00000
# 25%                       0.00000
# 50%                       1.50000
# 75%                       3.32000
# max                      13.80000

# %% [markdown]
# - Data is right skewed as COVID-19 hit a peak early on and died down.
# - Mean new deaths per case is around 1%
# - Mean total deaths per case is around 1.6%
# - Mean hospitalised patient per new case is around 4.93%
# - People who are fully vaccinated against the total number of vaccinations is around 36%

# %%
df['continent'].value_counts()
# Out:
# Africa           47998
# Europe           45001
# Asia             44688
# North America    32026
# Oceania          14074
# 0                11984
# South America    11545
# Name: continent, dtype: int64

# %%
df[df['continent'] == 0].head(1)
# Out:
#      iso_code continent location       date  total_cases  new_cases  \
# 897  OWID_AFR         0   Africa 2020-02-13      0.00000    0.00000
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 897             0.00000       0.00000     0.00000              0.00000
#
#      total_cases_per_million  new_cases_per_million  \
# 897                  0.00000                0.00000
#
#      new_cases_smoothed_per_million  total_deaths_per_million  \
# 897                         0.00000                   0.00000
#
#      new_deaths_per_million  new_deaths_smoothed_per_million  \
# 897                 0.00000                          0.00000
#
#      reproduction_rate  icu_patients  icu_patients_per_million  hosp_patients  \
# 897            0.00000       0.00000                   0.00000        0.00000
#
#      hosp_patients_per_million  weekly_icu_admissions  \
# 897                    0.00000                0.00000
#
#      weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 897                            0.00000                 0.00000
#
#      weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 897                             0.00000      0.00000    0.00000
#
#      total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 897                   0.00000                 0.00000             0.00000
#
#      new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 897                          0.00000        0.00000         0.00000
#
#     tests_units  total_vaccinations  people_vaccinated  \
# 897           0             0.00000            0.00000
#
#      people_fully_vaccinated  total_boosters  new_vaccinations  \
# 897                  0.00000         0.00000           0.00000
#
#      new_vaccinations_smoothed  total_vaccinations_per_hundred  \
# 897                    0.00000                         0.00000
#
#      people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 897                        0.00000                              0.00000
#
#      total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 897                     0.00000                                0.00000
#
#      new_people_vaccinated_smoothed  \
# 897                         0.00000
#
#      new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 897                                     0.00000           0.00000
#
#           population  population_density  median_age  aged_65_older  \
# 897 1392394303.00000             0.00000     0.00000        0.00000
#
#      aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 897        0.00000         0.00000          0.00000                0.00000
#
#      diabetes_prevalence  female_smokers  male_smokers  \
# 897              0.00000         0.00000       0.00000
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 897                 0.00000                     0.00000          0.00000
#
#      human_development_index  excess_mortality_cumulative_absolute  \
# 897                  0.00000                               0.00000
#
#      excess_mortality_cumulative  excess_mortality  \
# 897                      0.00000           0.00000
#
#      excess_mortality_cumulative_per_million  month  year  day
# 897                                  0.00000      2  2020   13

# %%
df[df['continent'] == 0]['iso_code'].value_counts()
# Out:
# OWID_WRL    930
# OWID_LMC    930
# OWID_HIC    930
# OWID_NAM    930
# OWID_UMC    930
# OWID_ASI    930
# OWID_EUR    929
# OWID_EUN    929
# OWID_OCE    927
# OWID_INT    914
# OWID_AFR    908
# OWID_SAM    899
# OWID_LIC    898
# Name: iso_code, dtype: int64

# %%
df[df['continent'] != 0].head(1)
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24      5.00000    5.00000
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0             0.00000       0.00000     0.00000              0.00000
#
#    total_cases_per_million  new_cases_per_million  \
# 0                  0.12500                0.12500
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                         0.00000                   0.00000
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                 0.00000                          0.00000            0.00000
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0       0.00000                   0.00000        0.00000
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                    0.00000                0.00000
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                            0.00000                 0.00000
#
#    weekly_hosp_admissions_per_million  total_tests  new_tests  \
# 0                             0.00000      0.00000    0.00000
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                   0.00000                 0.00000             0.00000
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                          0.00000        0.00000         0.00000           0
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0             0.00000            0.00000                  0.00000
#
#    total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# 0         0.00000           0.00000                    0.00000
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                         0.00000                        0.00000
#
#    people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                              0.00000                     0.00000
#
#    new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# 0                                0.00000                         0.00000
#
#    new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 0                                     0.00000           8.33000
#
#       population  population_density  median_age  aged_65_older  \
# 0 40099462.00000            54.42200    18.60000        2.58100
#
#    aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1.33700      1803.98700          0.00000              597.02900
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0              9.59000         0.00000       0.00000                37.74600
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                     0.50000         64.83000                  0.51100
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                               0.00000                      0.00000
#
#    excess_mortality  excess_mortality_cumulative_per_million  month  year  day
# 0           0.00000                                  0.00000      2  2020   24

# %% [markdown]
# - continent == 0 means everything but countries filter, continent != 0 means country filter

# %%
countries = df[df['continent'] != 0]

# %%
countries.shape
# Out:
# (195332, 70)

# %% [markdown]
# ### 3.1 Features against time for world data

# %%
def timeplot(feature):
    plt.figure(figsize = (11,7))
    sns.lineplot(x='date', y=feature, data=df[df['iso_code'] == 'OWID_WRL']).set_title(f'{feature} vs date')
    plt.show()

# %%
timeplot('new_cases_smoothed')

# %% [markdown]
# - New cases per day in the world peaked some time between January and February 2022 and it seems like it is starting to climb again.

# %%
timeplot('new_deaths_smoothed')

# %% [markdown]
# - Deaths have been decreasing since early 2021 although it spiked around the time the cases spiked. This perhaps may be linked to vaccinations.

# %%
timeplot('new_vaccinations_smoothed')

# %% [markdown]
# - COVID vaccines were introduced at around the end of 2020 and shortly after that, the deaths started to decrease.

# %% [markdown]
# Exploring continental data:

# %%
continents = ['OWID_AFR', 'OWID_ASI', 'OWID_NAM', 'OWID_OCE', 'OWID_SAM', 'OWID_EUR']

# %% [markdown]
# How do features distribute among the continents?

# %%
def piechart(feature):
    table = df[df['iso_code'].isin(continents)].groupby(['iso_code', 'location']).agg({'population':'max', feature:'max'}).reset_index()
    table[f'{feature}_per_population'] = (table[feature] / table['population']) * 100
    
    labels = table['location']
    data = table[f'{feature}_per_population']
    colors = sns.color_palette('pastel')
    
    plt.figure(figsize = (12,8))
    plt.pie(data, labels = labels, colors = colors, autopct='%.1f%%')
    plt.title(f'{feature}_per_population vs continent')
    plt.show()
    return table

# %%
a = piechart('total_cases')

# %% [markdown]
# - Europe had the most cases for its population followed by Oceania. Africa seems to be mostly not infected. Perhaps a better metric would be to look at the feature against the total_cases

# %%
def piechartcases(feature):
    table = df[df['iso_code'].isin(continents)].groupby(['iso_code', 'location']).agg({'total_cases':'max', feature:'max'}).reset_index()
    table[f'{feature}_per_total_cases'] = (table[feature] / table['total_cases']) * 100
    
    labels = table['location']
    data = table[f'{feature}_per_total_cases']
    colors = sns.color_palette('pastel')
    
    plt.figure(figsize = (12,8))
    plt.pie(data, labels = labels, colors = colors, autopct='%.1f%%')
    plt.title(f'{feature}_per_total_cases vs continent')
    plt.show()
    return table

# %%
b = piechartcases('total_deaths')

# %% [markdown]
# - Now, Africa seems to be one of continents that was mostly affected by deaths. It had a 2% death ratio per infected and thi amounts to about 28% of the continents total deaths per total cases.

# %%
c = piechart('people_vaccinated')

# %% [markdown]
# - Each continent is almost equally distributed in total vaccinations for its population except from Africa, which is much less.

# %% [markdown]
# ### 3.2 Exploring features against population

# %%
def population_table(feature):
    table = countries.groupby(['iso_code', 'location']).agg({'population':'max', feature:'max'})
    table = table[table['population'] > 0]
    table[f'{feature}_per_population'] = table[feature] / table['population']
    table = table.sort_values(f'{feature}_per_population', ascending=False).head(10).reset_index()
    return table

# %%
def population_plot(table):
    plt.figure(figsize = (10,5))
    sns.barplot(x=table.iloc[:,1], y=table.iloc[:,-1], data=table)
    plt.xticks(rotation=45)

# %%
population_table('total_deaths')
# Out:
#   iso_code                location     population  total_deaths  \
# 0      PER                    Peru 33715472.00000  214694.00000
# 1      BGR                Bulgaria  6885868.00000   37451.00000
# 2      BIH  Bosnia and Herzegovina  3270943.00000   15923.00000
# 3      HUN                 Hungary  9709786.00000   46886.00000
# 4      GEO                 Georgia  3757980.00000   16869.00000
# 5      MKD         North Macedonia  2103330.00000    9398.00000
# 6      MNE              Montenegro   627859.00000    2755.00000
# 7      HRV                 Croatia  4060135.00000   16420.00000
# 8      CZE                 Czechia 10510750.00000   40587.00000
# 9      MDA                 Moldova  3061506.00000   11630.00000
#
#    total_deaths_per_population
# 0                      0.00637
# 1                      0.00544
# 2                      0.00487
# 3                      0.00483
# 4                      0.00449
# 5                      0.00447
# 6                      0.00439
# 7                      0.00404
# 8                      0.00386
# 9                      0.00380

# %%
population_plot(population_table('total_deaths'))

# %% [markdown]
# - The top 10 countries who have suffered from COVID-19 in terms of death in the world.

# %%
population_plot(population_table('total_cases'))

# %% [markdown]
# - The countries that have had the most cases for their population in the world.

# %%
population_plot(population_table('total_tests'))

# %% [markdown]
# - The countries that have been tested the most for their population in the world.

# %%
population_plot(population_table('total_vaccinations'))

# %% [markdown]
# - The countries that their been vaccinated the most for their population.

# %% [markdown]
# If we compare the vaccination rate for the country with the highest death rate i.e. Peru to Gibraltar, the country with highest vaccination rate, we can perhaps find a trend:

# %%
def timeplotcountry(country_1, country_2, feature):
    countries = [country_1, country_2]
    plt.figure(figsize = (11,7))
    sns.lineplot(x='date', y=feature, data=df[df['location'].isin(countries)], hue='location').set_title(f'{feature} vs date')
    plt.show()

# %%
timeplotcountry('Gibraltar', 'Peru', 'new_people_vaccinated_smoothed')

# %%
timeplotcountry('Gibraltar', 'Peru', 'new_deaths_smoothed')

# %%
df[df['location'] == 'Peru']['population'].max()
# Out:
# 33715472.0

# %%
df[df['location'] == 'Gibraltar']['population'].max()
# Out:
# 32670.0

# %% [markdown]
# - Not a good indicator as the population difference is significant. Hence, test on countries with similar population.

# %%
df[df['continent'] != 0].groupby('location').agg({'population':'max'}).sort_values('population', ascending=False).head(20)
# Out:
#                                    population
# location
# China                        1425893464.00000
# India                        1407563842.00000
# United States                 336997624.00000
# Indonesia                     273753191.00000
# Pakistan                      231402116.00000
# Brazil                        214326223.00000
# Nigeria                       213401323.00000
# Bangladesh                    169356251.00000
# Russia                        145102755.00000
# Mexico                        126705138.00000
# Japan                         124612530.00000
# Ethiopia                      120283026.00000
# Philippines                   113880328.00000
# Egypt                         109262178.00000
# Vietnam                        97468028.00000
# Democratic Republic of Congo   95894118.00000
# Iran                           87923432.00000
# Turkey                         84775404.00000
# Germany                        83408554.00000
# Thailand                       71601103.00000

# %%
def timeplotcountry(country_1, country_2, country_3, feature):
    countries = [country_1, country_2, country_3]
    plt.figure(figsize = (11,7))
    sns.lineplot(x='date', y=feature, data=df[df['location'].isin(countries)], hue='location').set_title(f'{feature} vs date')
    plt.show()

# %%
timeplotcountry('Indonesia', 'United States', 'Brazil', 'new_people_vaccinated_smoothed')

# %%
timeplotcountry('Indonesia', 'United States', 'Brazil', 'new_deaths_smoothed')

# %% [markdown]
# - At the time Indonesia were late in getting the vaccine relative to the US, The US deaths started to decrease whilst Indonesia's deaths started to increase. When Indonesia started to vaccine their people, the deaths dropped off significantly.
# - The deaths of Indonesia before the vaccine were low compared to the US. This signifies there are more factors than just a vaccine. Also, the US deaths also increased significantly again, even after the vaccine.
# - Brazil seems to follow the same trend of Indonesia after being vaccinated such that the deaths also reduce significantly and stay low.

# %% [markdown]
# ### 3.3 Exploring feature against feature

# %% [markdown]
# **Fully vaccinated vs partly vaccinated**

# %%
df.loc[df['iso_code'] == 'OWID_WRL', ['people_vaccinated', 'people_fully_vaccinated']]
# Out:
#         people_vaccinated  people_fully_vaccinated
# 203789            0.00000                  0.00000
# 203790            0.00000                  0.00000
# 203791            0.00000                  0.00000
# 203792            0.00000                  0.00000
# 203793            0.00000                  0.00000
# ...                   ...                      ...
# 204714   5310306047.00000         4879339706.00000
# 204715   5310845603.00000         4880316912.00000
# 204716   5311108413.00000         4880924263.00000
# 204717   5311272367.00000         4881398019.00000
# 204718   5312088076.00000         4882574379.00000
#
# [930 rows x 2 columns]

# %%
def vaccination_piechart(feature):
    plt.figure(figsize = (11,7))
    df.loc[df['iso_code'] == 'OWID_WRL', ['people_vaccinated', feature]].max().plot.pie(explode=[0,0.1],autopct='%1.1f%%',shadow=True)
    plt.ylabel('')
    plt.show()

# %%
vaccination_piechart('people_fully_vaccinated')

# %% [markdown]
# - For the people that have been vaccinated, almost half of them are fully vaccinated.

# %%
vaccination_piechart('population')

# %% [markdown]
# - Around 40% of the world are vaccinated.

# %% [markdown]
# How does the full vs partial vaccination vary across each continent?

# %%
world_vaccination = df.loc[df['iso_code'].isin(continents), ['iso_code', 'location', 'population', 'people_vaccinated', 'people_fully_vaccinated']].groupby(['iso_code', 'location']).max().reset_index()
world_vaccination
# Out:
#    iso_code       location       population  people_vaccinated  \
# 0  OWID_AFR         Africa 1392394303.00000    371832834.00000
# 1  OWID_ASI           Asia 4693235454.00000   3583871129.00000
# 2  OWID_EUR         Europe  748655221.00000    516472782.00000
# 3  OWID_NAM  North America  596315269.00000    441110977.00000
# 4  OWID_OCE        Oceania   44491772.00000     29051147.00000
# 5  OWID_SAM  South America  433956670.00000    369749207.00000
#
#    people_fully_vaccinated
# 0          293273808.00000
# 1         3352353329.00000
# 2          494421137.00000
# 3          382636649.00000
# 4           27866815.00000
# 5          332022641.00000

# %%
plt.figure(figsize = (10,7))

x = world_vaccination['location']

y = world_vaccination['population']
z = world_vaccination['people_vaccinated']
k = world_vaccination['people_fully_vaccinated']

X_axis = np.arange(len(x))

plt.bar(X_axis - 0.2, y, 0.2, label = 'population')
plt.bar(X_axis, z, 0.2, label = 'people_vaccinated')
plt.bar(X_axis + 0.2, k, 0.2, label = 'people_fully_vaccinated')

plt.xticks(X_axis, x)
plt.ylabel("")
plt.title("Difference in vaccination across the continents")
plt.legend()
plt.show()

# %% [markdown]
# - Africa is least vaccinated relative to its population.

# %%
def piechartcontinents():
    table = df.loc[df['iso_code'].isin(continents), ['iso_code', 'location', 'population', 'people_vaccinated', 'people_fully_vaccinated']].groupby(['iso_code', 'location']).max().reset_index()
    table[f'people_fully_vaccinated_per_people_vaccinated'] = table['people_fully_vaccinated'] / table['people_vaccinated']
    
    labels = table['location']
    data = table[f'people_fully_vaccinated_per_people_vaccinated']
    colors = sns.color_palette('pastel')
    
    plt.figure(figsize = (12,8))
    plt.pie(data, labels = labels, colors = colors, autopct='%.1f%%')
    plt.title(f'people_fully_vaccinated_per_people_vaccinated vs continent')
    plt.show()

# %%
piechartcontinents()

# %% [markdown]
# - Full vs partial vaccination is similar across each continent.

# %% [markdown]
# **Testing vs Features**

# %%
def test_series(feature_1, feature_2, feature_3, feature_4):
    table = countries.groupby('date').agg({feature_1:'max', feature_2:'max', feature_3:'max', feature_4:'max'})
    plot , ax = plt.subplots(4, 1, figsize=(18,20))
    sns.lineplot(x='date', y=feature_1, data=table, ax = ax[0]).set_title(f'{feature_1} vs date')
    sns.lineplot(x='date', y=feature_2, data=table, ax = ax[1]).set_title(f'{feature_2} vs date')
    sns.lineplot(x='date', y=feature_3, data=table, ax = ax[2]).set_title(f'{feature_3} vs date')
    sns.lineplot(x='date', y=feature_4, data=table, ax = ax[3]).set_title(f'{feature_4} vs date')
    plt.show()

# %%
test_series('new_tests_smoothed_per_thousand', 'new_cases_smoothed', 'new_vaccinations_smoothed', 'new_deaths_smoothed')

# %% [markdown]
# - As testing increased, the number of cases increased as more people with COVID were able to be indentified.
# - Vaccinations will peak at one point and decrease as the aim of the vaccination was to try vaccinate as many people as possible. It most likely affected the number of people that died as its severity reduced but it did not stop other people from catching COVID.

# %% [markdown]
# ### 3.4 COVID vs Year

# %%
def time_feature(feature, time):
    table = countries.groupby(time).agg({feature:'sum'}).reset_index()
    plt.figure(figsize = (6,4))
    sns.barplot(x=time, y=feature, data=table).set_title(f'{feature} vs {time}')
    plt.show()

# %%
time_feature('total_cases', 'year')

# %% [markdown]
# - Total cases increased each year.

# %%
time_feature('total_deaths', 'year')

# %% [markdown]
# - Deaths decreased after 2021.

# %%
time_feature('total_vaccinations', 'year')

# %% [markdown]
# - Vaccinations increased by almost double in 2022.

# %% [markdown]
# ### 3.5 World Maps

# %% [markdown]
# #### 3.5.1 Cleaning

# %% [markdown]
# Load geopandas coordinates to map to df

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world.head()
# Out:
#      pop_est      continent                      name iso_a3     gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI     8374.00000
# 1   53950935         Africa                  Tanzania    TZA   150600.00000
# 2     603253         Africa                 W. Sahara    ESH      906.50000
# 3   35623680  North America                    Canada    CAN  1674000.00000
# 4  326625791  North America  United States of America    USA 18560000.00000
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
world[['iso_a3', 'continent', 'name']]
# Out:
#     iso_a3      continent                      name
# 0      FJI        Oceania                      Fiji
# 1      TZA         Africa                  Tanzania
# 2      ESH         Africa                 W. Sahara
# 3      CAN  North America                    Canada
# 4      USA  North America  United States of America
# ..     ...            ...                       ...
# 172    SRB         Europe                    Serbia
# 173    MNE         Europe                Montenegro
# 174    -99         Europe                    Kosovo
# 175    TTO  North America       Trinidad and Tobago
# 176    SSD         Africa                  S. Sudan
#
# [177 rows x 3 columns]

# %%
df_world = df[['iso_code', 'continent', 'location']].groupby(['iso_code', 'continent', 'location']).count().reset_index()
df_world
# Out:
#     iso_code      continent      location
# 0        ABW  North America         Aruba
# 1        AFG           Asia   Afghanistan
# 2        AGO         Africa        Angola
# 3        AIA  North America      Anguilla
# 4        ALB         Europe       Albania
# ..       ...            ...           ...
# 239      WSM        Oceania         Samoa
# 240      YEM           Asia         Yemen
# 241      ZAF         Africa  South Africa
# 242      ZMB         Africa        Zambia
# 243      ZWE         Africa      Zimbabwe
#
# [244 rows x 3 columns]

# %% [markdown]
# Geopandas only has 177 countries that can be mapped out of the 244 available countries in the df.

# %% [markdown]
# - Step 1: Compare iso codes

# %%
geo_list = world['iso_a3'].to_list()
df_list = df_world['iso_code'].to_list()

# %%
def diff(list1, list2):
    c = set(list1).union(set(list2))  # or c = set(list1) | set(list2)
    d = set(list1).intersection(set(list2))  # or d = set(list1) & set(list2)
    return list(c - d)

# %%
diff(df_list, geo_list)
# Out:
# ['OWID_EUN',
#  'WSM',
#  'MSR',
#  'OWID_HIC',
#  'MCO',
#  'FRA',
#  'BMU',
#  'LIE',
#  'DMA',
#  'OWID_LMC',
#  'BRB',
#  'OWID_KOS',
#  'VGB',
#  'SPM',
#  'CPV',
#  'VCT',
#  'BES',
#  'NIU',
#  'TCA',
#  'MLT',
#  'SXM',
#  'ATA',
#  'MNP',
#  'OWID_LIC',
#  'IMN',
#  'GUM',
#  'SMR',
#  'ABW',
#  'LCA',
#  'GIB',
#  'SHN',
#  'OWID_NAM',
#  'MHL',
#  'OWID_INT',
#  'WLF',
#  'OWID_CYN',
#  'SGP',
#  'KNA',
#  'MDV',
#  'ATF',
#  'OWID_EUR',
#  'NOR',
#  '-99',
#  'GGY',
#  'FRO',
#  'CYM',
#  'KIR',
#  'BHR',
#  'HKG',
#  'OWID_AFR',
#  'OWID_SAM',
#  'AIA',
#  'COK',
#  'TON',
#  'TUV',
#  'CUW',
#  'OWID_UMC',
#  'SYC',
#  'FSM',
#  'PLW',
#  'OWID_OCE',
#  'AND',
#  'VIR',
#  'STP',
#  'JEY',
#  'MUS',
#  'GRD',
#  'NRU',
#  'MAC',
#  'PCN',
#  'PYF',
#  'TKL',
#  'VAT',
#  'ATG',
#  'OWID_WRL',
#  'OWID_ASI',
#  'COM']

# %% [markdown]
# Deal with -99

# %%
world[world['iso_a3'] == '-99']
# Out:
#       pop_est continent        name iso_a3    gdp_md_est  \
# 21    5320045    Europe      Norway    -99  364700.00000
# 43   67106161    Europe      France    -99 2699000.00000
# 160    265100      Asia   N. Cyprus    -99    3600.00000
# 167   3500000    Africa  Somaliland    -99   12250.00000
# 174   1895250    Europe      Kosovo    -99   18490.00000
#
#                                               geometry
# 21   MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...
# 43   MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...
# 160  POLYGON ((32.73178 35.14003, 32.80247 35.14550...
# 167  POLYGON ((48.94820 11.41062, 48.94820 11.41062...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...

# %%
df_world[df_world['location'].isin(world[world['iso_a3'] == '-99']['name'])]
# Out:
#      iso_code continent location
# 67        FRA    Europe   France
# 151       NOR    Europe   Norway
# 163  OWID_KOS    Europe   Kosovo

# %%
world.at[21,'iso_a3'] = 'NOR'
world.at[43,'iso_a3'] = 'FRA'
world.at[174,'iso_a3'] = 'OWID_KOS'

# %% [markdown]
# Deal with other 3:

# %%
df_world[df_world['location'].str.contains('Somali')]
# Out:
#     iso_code continent location
# 198      SOM    Africa  Somalia

# %% [markdown]
# - No Somaliland in my df

# %%
df_world[df_world['location'].str.contains('Cyprus')]
# Out:
#      iso_code continent         location
# 49        CYP    Europe           Cyprus
# 158  OWID_CYN      Asia  Northern Cyprus

# %%
world.at[160,'iso_a3'] = 'OWID_CYN'

# %% [markdown]
# Deal with the rest:

# %%
pd.set_option('display.max_rows', 208)

# %%
world[world['iso_a3'].isin(diff(df_list, geo_list))]
# Out:
#       pop_est                continent                    name    iso_a3  \
# 21    5320045                   Europe                  Norway       NOR
# 23        140  Seven seas (open ocean)  Fr. S. Antarctic Lands       ATF
# 43   67106161                   Europe                  France       FRA
# 159      4050               Antarctica              Antarctica       ATA
# 160    265100                     Asia               N. Cyprus  OWID_CYN
# 167   3500000                   Africa              Somaliland       -99
# 174   1895250                   Europe                  Kosovo  OWID_KOS
#
#        gdp_md_est                                           geometry
# 21   364700.00000  MULTIPOLYGON (((15.14282 79.67431, 15.52255 80...
# 23       16.00000  POLYGON ((68.93500 -48.62500, 69.58000 -48.940...
# 43  2699000.00000  MULTIPOLYGON (((-51.65780 4.15623, -52.24934 3...
# 159     810.00000  MULTIPOLYGON (((-48.66062 -78.04702, -48.15140...
# 160    3600.00000  POLYGON ((32.73178 35.14003, 32.80247 35.14550...
# 167   12250.00000  POLYGON ((48.94820 11.41062, 48.94820 11.41062...
# 174   18490.00000  POLYGON ((20.59025 41.85541, 20.52295 42.21787...

# %%
print(df_world[df_world['location'].str.contains('Antarctic')])
# Out:
# Empty DataFrame
# Columns: [iso_code, continent, location]
# Index: []

# %% [markdown]
# - The codes in world dataset but not in df

# %%
test = df_world[(df_world['iso_code'].isin(diff(df_list, geo_list)))]
test[test['continent'] != 0]
# Out:
#      iso_code      continent                          location
# 0         ABW  North America                             Aruba
# 3         AIA  North America                          Anguilla
# 5         AND         Europe                           Andorra
# 9         ATG  North America               Antigua and Barbuda
# 16        BES  North America   Bonaire Sint Eustatius and Saba
# 20        BHR           Asia                           Bahrain
# 25        BMU  North America                           Bermuda
# 28        BRB  North America                          Barbados
# 41        COK        Oceania                      Cook Islands
# 43        COM         Africa                           Comoros
# 44        CPV         Africa                        Cape Verde
# 47        CUW  North America                           Curacao
# 48        CYM  North America                    Cayman Islands
# 53        DMA  North America                          Dominica
# 67        FRA         Europe                            France
# 68        FRO         Europe                    Faeroe Islands
# 69        FSM        Oceania              Micronesia (country)
# 73        GGY         Europe                          Guernsey
# 75        GIB         Europe                         Gibraltar
# 81        GRD  North America                           Grenada
# 84        GUM        Oceania                              Guam
# 86        HKG           Asia                         Hong Kong
# 92        IMN         Europe                       Isle of Man
# 101       JEY         Europe                            Jersey
# 108       KIR        Oceania                          Kiribati
# 109       KNA  North America             Saint Kitts and Nevis
# 116       LCA  North America                       Saint Lucia
# 117       LIE         Europe                     Liechtenstein
# 123       MAC           Asia                             Macao
# 125       MCO         Europe                            Monaco
# 128       MDV           Asia                          Maldives
# 130       MHL        Oceania                  Marshall Islands
# 133       MLT         Europe                             Malta
# 137       MNP        Oceania          Northern Mariana Islands
# 140       MSR  North America                        Montserrat
# 141       MUS         Africa                         Mauritius
# 149       NIU        Oceania                              Niue
# 151       NOR         Europe                            Norway
# 153       NRU        Oceania                             Nauru
# 158  OWID_CYN           Asia                   Northern Cyprus
# 163  OWID_KOS         Europe                            Kosovo
# 173       PCN        Oceania                          Pitcairn
# 176       PLW        Oceania                             Palau
# 184       PYF        Oceania                  French Polynesia
# 192       SGP           Asia                         Singapore
# 193       SHN         Africa                      Saint Helena
# 197       SMR         Europe                        San Marino
# 199       SPM  North America         Saint Pierre and Miquelon
# 202       STP         Africa             Sao Tome and Principe
# 208       SXM  North America         Sint Maarten (Dutch part)
# 209       SYC         Africa                        Seychelles
# 211       TCA  North America          Turks and Caicos Islands
# 216       TKL        Oceania                           Tokelau
# 219       TON        Oceania                             Tonga
# 223       TUV        Oceania                            Tuvalu
# 231       VAT         Europe                           Vatican
# 232       VCT  North America  Saint Vincent and the Grenadines
# 234       VGB  North America            British Virgin Islands
# 235       VIR  North America      United States Virgin Islands
# 238       WLF        Oceania                 Wallis and Futuna
# 239       WSM        Oceania                             Samoa

# %%
for country in test['location']:
    print(world[world['name'].str.contains(country.split(' ')[0])]['name'])
# Out:
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# 17    Dominican Rep.
# Name: name, dtype: object
# 43    France
# Name: name, dtype: object
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# 21    Norway
# Name: name, dtype: object
# Series([], Name: name, dtype: object)
# 25            South Africa
# 66    Central African Rep.
# Name: name, dtype: object
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# 174    Kosovo
# Name: name, dtype: object
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# 95    North Korea
# Name: name, dtype: object
# Series([], Name: name, dtype: object)
# 25    South Africa
# 96     South Korea
# Name: name, dtype: object
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)
# 4      United States of America
# 84         United Arab Emirates
# 143              United Kingdom
# Name: name, dtype: object
# Series([], Name: name, dtype: object)
# Series([], Name: name, dtype: object)

# %%
world[world['name'].str.contains('Aruba')]['name']
# Out:
# Series([], Name: name, dtype: object)

# %%
print(df_world[df_world['location'].str.contains('Dominican')])
print(df_world[df_world['location'].str.contains('South')])
print(df_world[df_world['location'].str.contains('Central')])
# Out:
#    iso_code      continent            location
# 55      DOM  North America  Dominican Republic
#      iso_code continent       location
# 110       KOR      Asia    South Korea
# 168  OWID_SAM         0  South America
# 201       SSD    Africa    South Sudan
# 241       ZAF    Africa   South Africa
#    iso_code continent                  location
# 32      CAF    Africa  Central African Republic

# %%
world[world['name'].str.contains('Sudan')]
# Out:
#       pop_est continent      name iso_a3   gdp_md_est  \
# 14   37345935    Africa     Sudan    SDN 176300.00000
# 176  13026129    Africa  S. Sudan    SSD  20880.00000
#
#                                               geometry
# 14   POLYGON ((24.56737 8.22919, 23.80581 8.66632, ...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...

# %% [markdown]
# Merge two tables together:

# %%
df.shape
# Out:
# (207316, 70)

# %%
# only use columns with new to get summed value 
merged = df.groupby(['iso_code', 'location']).sum().reset_index()

# %%
merged_df = world.merge(merged, how='left', left_on=['iso_a3'], right_on=['iso_code'])

# %%
merged_df.shape
# Out:
# (177, 73)

# %%
merged_df.isnull().sum()
# Out:
# pop_est                                       0
# continent                                     0
# name                                          0
# iso_a3                                        0
# gdp_md_est                                    0
# geometry                                      0
# iso_code                                      3
# location                                      3
# total_cases                                   3
# new_cases                                     3
# new_cases_smoothed                            3
# total_deaths                                  3
# new_deaths                                    3
# new_deaths_smoothed                           3
# total_cases_per_million                       3
# new_cases_per_million                         3
# new_cases_smoothed_per_million                3
# total_deaths_per_million                      3
# new_deaths_per_million                        3
# new_deaths_smoothed_per_million               3
# reproduction_rate                             3
# icu_patients                                  3
# icu_patients_per_million                      3
# hosp_patients                                 3
# hosp_patients_per_million                     3
# weekly_icu_admissions                         3
# weekly_icu_admissions_per_million             3
# weekly_hosp_admissions                        3
# weekly_hosp_admissions_per_million            3
# total_tests                                   3
# new_tests                                     3
# total_tests_per_thousand                      3
# new_tests_per_thousand                        3
# new_tests_smoothed                            3
# new_tests_smoothed_per_thousand               3
# positive_rate                                 3
# tests_per_case                                3
# total_vaccinations                            3
# people_vaccinated                             3
# people_fully_vaccinated                       3
# total_boosters                                3
# new_vaccinations                              3
# new_vaccinations_smoothed                     3
# total_vaccinations_per_hundred                3
# people_vaccinated_per_hundred                 3
# people_fully_vaccinated_per_hundred           3
# total_boosters_per_hundred                    3
# new_vaccinations_smoothed_per_million         3
# new_people_vaccinated_smoothed                3
# new_people_vaccinated_smoothed_per_hundred    3
# stringency_index                              3
# population                                    3
# population_density                            3
# median_age                                    3
# aged_65_older                                 3
# aged_70_older                                 3
# gdp_per_capita                                3
# extreme_poverty                               3
# cardiovasc_death_rate                         3
# diabetes_prevalence                           3
# female_smokers                                3
# male_smokers                                  3
# handwashing_facilities                        3
# hospital_beds_per_thousand                    3
# life_expectancy                               3
# human_development_index                       3
# excess_mortality_cumulative_absolute          3
# excess_mortality_cumulative                   3
# excess_mortality                              3
# excess_mortality_cumulative_per_million       3
# month                                         3
# year                                          3
# day                                           3
# dtype: int64

# %%
world.shape
# Out:
# (177, 6)

# %%
merged_df.dropna(inplace=True)
merged_df.shape
# Out:
# (174, 73)

# %%
merged_df.head(1)
# Out:
#    pop_est continent  name iso_a3  gdp_md_est  \
# 0   920938   Oceania  Fiji    FJI  8374.00000
#
#                                             geometry iso_code location  \
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...      FJI     Fiji
#
#      total_cases   new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0 22211719.00000 67869.00000         67775.30800  279189.00000   876.00000
#
#    new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# 0            870.59400           24022797.78100            73402.85400
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                     73301.56700              301953.25100
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0               947.45000                        941.62300          523.63000
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0       0.00000                   0.00000        0.00000
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                    0.00000                0.00000
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                            0.00000                 0.00000
#
#    weekly_hosp_admissions_per_million    total_tests    new_tests  \
# 0                             0.00000 73025371.00000 402088.00000
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0               80878.78600               445.31900        555919.00000
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# 0                        615.70300        0.00000         0.00000
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0      65368336.00000     35432680.00000           27716899.00000
#
#    total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# 0   2179175.00000       28295.00000              1522173.00000
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                      7069.85000                     3832.17000
#
#    people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                           2997.68000                   235.70000
#
#    new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# 0                          1646292.00000                    708813.00000
#
#    new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# 0                                    76.64600       52262.49000
#
#        population  population_density  median_age  aged_65_older  \
# 0 852490420.00000         45696.16400 26369.20000     5738.52800
#
#    aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0     3027.84800   8024142.95000       1290.80000           380620.04000
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0          13359.78000      9404.40000   32085.60000                 0.00000
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                  2120.60000      62179.68000                685.04600
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                               0.00000                      0.00000
#
#    excess_mortality  excess_mortality_cumulative_per_million      month  \
# 0           0.00000                                  0.00000 5653.00000
#
#            year         day
# 0 1863245.00000 14426.00000

# %% [markdown]
# #### 3.5.2 Analysis

# %%
def worldmap(feature):
    table = merged_df
    table[f'{feature}_per_population'] = (table[feature] / table['population']) * 100
    table = table[table[f'{feature}_per_population'] < 10000] # remove any inf issues
    fig, ax = plt.subplots(1, 1, figsize=(14,9))
    name = 'total_' + feature.split('_')[1]
    plt.title(f'{name}_per_population')
    table[[f'{feature}_per_population', 'geometry']].plot(f'{feature}_per_population', ax=ax, legend=True, legend_kwds={'label': f'{name}_per_population', 'orientation':'horizontal'}, cmap='OrRd')
    plt.show()

# %%
worldmap('new_cases')

# %% [markdown]
# - Europe was infected by COVID the most followed by Australia and the US.

# %%
worldmap('new_deaths')

# %% [markdown]
# - South America, the US and some parts of Europe have high death count per population. However, when comparing death count to the number of people infected, it is a different story.

# %%
def worldmap_2(feature):
    table = merged_df
    table[f'{feature}_per_new_cases'] = (table[feature] / table['new_cases']) * 100
    table = table[table[f'{feature}_per_new_cases'] < 600] # remove any inf issues
    fig, ax = plt.subplots(1, 1, figsize=(14,9))
    name = 'total_' + feature.split('_')[1]
    plt.title(f'{name}_per_new_cases')
    table[[f'{feature}_per_new_cases', 'geometry']].plot(f'{feature}_per_new_cases', ax=ax, legend=True, legend_kwds={'label': f'{name}_per_new_cases', 'orientation':'horizontal'}, cmap='OrRd')
    plt.show()

# %%
worldmap_2('new_deaths')

# %% [markdown]
# - In this case, Yemen and some parts of Africa alongside Peru and Mexico seem to have the highest deaths for its population.

# %%
worldmap('new_people_vaccinated_smoothed')

# %% [markdown]
# - The world seems to be mostly vaccinated well apart from Africa.

# %% [markdown]
# ## 4. Load

# %% [markdown]
# Chapter 3 was an in depth look into the data to create useful analytics that may be useful to report. Hence, not all the visuals will be used for a simplified dashboard to get an image of what is going on around the world. For the dashboard, the imported dataset will be exported and a number of these visuals will be replicated.

# %%
df[df['iso_code'] == 'OWID_WRL'][['date', 'new_cases_smoothed', 'new_deaths_smoothed', 'new_vaccinations_smoothed']]
# Out:
#              date  new_cases_smoothed  new_deaths_smoothed  \
# 203789 2020-01-22             0.00000              0.00000
# 203790 2020-01-23             0.00000              0.00000
# 203791 2020-01-24             0.00000              0.00000
# 203792 2020-01-25             0.00000              0.00000
# 203793 2020-01-26             0.00000              0.00000
# ...           ...                 ...                  ...
# 204714 2022-08-04       1019857.14300           2446.57100
# 204715 2022-08-05        953741.14300           2433.71400
# 204716 2022-08-06       1039604.85700           2524.00000
# 204717 2022-08-07       1033869.42900           2525.14300
# 204718 2022-08-08       1020751.42900           2499.71400
#
#         new_vaccinations_smoothed
# 203789                    0.00000
# 203790                    0.00000
# 203791                    0.00000
# 203792                    0.00000
# 203793                    0.00000
# ...                           ...
# 204714                    0.00000
# 204715                    0.00000
# 204716                    0.00000
# 204717                    0.00000
# 204718                    0.00000
#
# [930 rows x 4 columns]

# %%
a
# Out:
#    iso_code       location       population     total_cases  \
# 0  OWID_AFR         Africa 1392394303.00000  12282287.00000
# 1  OWID_ASI           Asia 4693235454.00000 169918070.00000
# 2  OWID_EUR         Europe  748655221.00000 219407121.00000
# 3  OWID_NAM  North America  596315269.00000 109491859.00000
# 4  OWID_OCE        Oceania   44491772.00000  11694996.00000
# 5  OWID_SAM  South America  433956670.00000  62618916.00000
#
#    total_cases_per_population
# 0                     0.88210
# 1                     3.62049
# 2                    29.30683
# 3                    18.36140
# 4                    26.28575
# 5                    14.42976

# %%
b
# Out:
#    iso_code       location     total_cases  total_deaths  \
# 0  OWID_AFR         Africa  12282287.00000  256176.00000
# 1  OWID_ASI           Asia 169918070.00000 1457084.00000
# 2  OWID_EUR         Europe 219407121.00000 1889765.00000
# 3  OWID_NAM  North America 109491859.00000 1482132.00000
# 4  OWID_OCE        Oceania  11694996.00000   16878.00000
# 5  OWID_SAM  South America  62618916.00000 1318247.00000
#
#    total_deaths_per_total_cases
# 0                       2.08574
# 1                       0.85752
# 2                       0.86131
# 3                       1.35365
# 4                       0.14432
# 5                       2.10519

# %%
c
# Out:
#    iso_code       location       population  people_vaccinated  \
# 0  OWID_AFR         Africa 1392394303.00000    371832834.00000
# 1  OWID_ASI           Asia 4693235454.00000   3583871129.00000
# 2  OWID_EUR         Europe  748655221.00000    516472782.00000
# 3  OWID_NAM  North America  596315269.00000    441110977.00000
# 4  OWID_OCE        Oceania   44491772.00000     29051147.00000
# 5  OWID_SAM  South America  433956670.00000    369749207.00000
#
#    people_vaccinated_per_population
# 0                          26.70456
# 1                          76.36248
# 2                          68.98673
# 3                          73.97278
# 4                          65.29555
# 5                          85.20418

# %%
import pyodbc
from sqlalchemy import create_engine
import urllib

SERVER_NAME = 'DESKTOP-GR6T3L7'
DATABASE_NAME = 'CovidV2'

# connection string
conn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server}; \
                       SERVER=' + SERVER_NAME + '; \
                       DATABASE=' + DATABASE_NAME + '; \
                       Trusted_Connection=yes')

# cursor to extract data
cursor = conn.cursor()

# Use this to connect for saving data
quoted = urllib.parse.quote_plus('DRIVER={ODBC Driver 17 for SQL Server}; \
                       SERVER='+SERVER_NAME+'; \
                       DATABASE='+DATABASE_NAME+'; \
                       Trusted_Connection=yes')

# save the dataset into SQL database
engine = create_engine('mssql+pyodbc:///?odbc_connect={}'.format(quoted))
df.to_sql('initial_dataset', schema='dbo', con=engine, if_exists='replace')

# close port
cursor.close()
conn.close( 
)
print('Dataset appended.')
