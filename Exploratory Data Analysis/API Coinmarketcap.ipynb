# %% [markdown]
# # Coinmarketcap API Project

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import os
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Extract Data

# %%
# jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10 <---- to get the jupyter to work

# %%
my_api_key = 'd46ce64b-a724-4e6e-a7f7-4d4a704093ac'
test_api_key = '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509'

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': test_api_key,
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(e)

# %%
data.keys()
# Out:
# dict_keys(['status', 'data'])

# %%
data['data'][:1]
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 9660,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'store-of-value',
#    'state-channel',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures-portfolio',
#    'galaxy-digital-portfolio',
#    'huobi-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital-portfolio',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-portfolio'],
#   'max_supply': 21000000,
#   'circulating_supply': 19114287,
#   'total_supply': 19114287,
#   'platform': None,
#   'cmc_rank': 1,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2022-08-06T21:45:00.000Z',
#   'quote': {'USD': {'price': 23186.936239614737,
#     'volume_24h': 16093698062.637196,
#     'volume_change_24h': -43.8934,
#     'percent_change_1h': 0.13174299,
#     'percent_change_24h': 0.33375322,
#     'percent_change_7d': -3.15625852,
#     'percent_change_30d': 7.27064868,
#     'percent_change_60d': -26.13905213,
#     'percent_change_90d': -32.64182853,
#     'market_cap': 443201753934.69684,
#     'market_cap_dominance': 40.3562,
#     'fully_diluted_market_cap': 486925661031.91,
#     'tvl': None,
#     'last_updated': '2022-08-06T21:45:00.000Z'}}}]

# %%
# json normalize pandas
df = pd.json_normalize(data['data']).head()
df
# Out:
#      id      name symbol      slug  num_market_pairs  \
# 0     1   Bitcoin    BTC   bitcoin              9660
# 1  1027  Ethereum    ETH  ethereum              5922
# 2   825    Tether   USDT    tether             37474
# 3  3408  USD Coin   USDC  usd-coin              5175
# 4  1839       BNB    BNB       bnb              1052
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2015-02-25T00:00:00.000Z
# 3  2018-10-08T00:00:00.000Z
# 4  2017-07-25T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 3  [medium-of-exchange, stablecoin, asset-backed-...          NaN
# 4  [marketplace, centralized-exchange, payments, ...  200000000.0
#
#    circulating_supply  total_supply  ...  quote.USD.market_cap  \
# 0        1.911429e+07  1.911429e+07  ...          4.432018e+11
# 1        1.218576e+08  1.218576e+08  ...          2.089779e+11
# 2        6.647653e+10  6.915898e+10  ...          6.648400e+10
# 3        5.428995e+10  5.428995e+10  ...          5.429216e+10
# 4        1.613373e+08  1.613373e+08  ...          5.143413e+10
#
#    quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         40.3562                        4.869257e+11
# 1                         19.0287                        2.089779e+11
# 2                          6.0538                        6.916676e+10
# 3                          4.9436                        5.429216e+10
# 4                          4.6834                        6.375977e+10
#
#    quote.USD.tvl    quote.USD.last_updated platform.id  platform.name  \
# 0            NaN  2022-08-06T21:45:00.000Z         NaN            NaN
# 1            NaN  2022-08-06T21:45:00.000Z         NaN            NaN
# 2            NaN  2022-08-06T21:45:00.000Z      1027.0       Ethereum
# 3            NaN  2022-08-06T21:45:00.000Z      1027.0       Ethereum
# 4            NaN  2022-08-06T21:45:00.000Z         NaN            NaN
#
#    platform.symbol  platform.slug                      platform.token_address
# 0              NaN            NaN                                         NaN
# 1              NaN            NaN                                         NaN
# 2              ETH       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              ETH       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 4              NaN            NaN                                         NaN
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  5 non-null      int64
#  1   name                                5 non-null      object
#  2   symbol                              5 non-null      object
#  3   slug                                5 non-null      object
#  4   num_market_pairs                    5 non-null      int64
#  5   date_added                          5 non-null      object
#  6   tags                                5 non-null      object
#  7   max_supply                          2 non-null      float64
#  8   circulating_supply                  5 non-null      float64
#  9   total_supply                        5 non-null      float64
#  10  platform                            0 non-null      float64
#  11  cmc_rank                            5 non-null      int64
#  12  self_reported_circulating_supply    0 non-null      float64
#  13  self_reported_market_cap            0 non-null      float64
#  14  tvl_ratio                           0 non-null      float64
#  15  last_updated                        5 non-null      object
#  16  quote.USD.price                     5 non-null      float64
#  17  quote.USD.volume_24h                5 non-null      float64
#  18  quote.USD.volume_change_24h         5 non-null      float64
#  19  quote.USD.percent_change_1h         5 non-null      float64
#  20  quote.USD.percent_change_24h        5 non-null      float64
#  21  quote.USD.percent_change_7d         5 non-null      float64
#  22  quote.USD.percent_change_30d        5 non-null      float64
#  23  quote.USD.percent_change_60d        5 non-null      float64
#  24  quote.USD.percent_change_90d        5 non-null      float64
#  25  quote.USD.market_cap                5 non-null      float64
#  26  quote.USD.market_cap_dominance      5 non-null      float64
#  27  quote.USD.fully_diluted_market_cap  5 non-null      float64
#  28  quote.USD.tvl                       0 non-null      float64
#  29  quote.USD.last_updated              5 non-null      object
#  30  platform.id                         2 non-null      float64
#  31  platform.name                       2 non-null      object
#  32  platform.symbol                     2 non-null      object
#  33  platform.slug                       2 non-null      object
#  34  platform.token_address              2 non-null      object
# dtypes: float64(21), int64(3), object(11)
# memory usage: 1.5+ KB

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# symbol                                0
# slug                                  0
# num_market_pairs                      0
# date_added                            0
# tags                                  0
# max_supply                            3
# circulating_supply                    0
# total_supply                          0
# platform                              5
# cmc_rank                              0
# self_reported_circulating_supply      5
# self_reported_market_cap              5
# tvl_ratio                             5
# last_updated                          0
# quote.USD.price                       0
# quote.USD.volume_24h                  0
# quote.USD.volume_change_24h           0
# quote.USD.percent_change_1h           0
# quote.USD.percent_change_24h          0
# quote.USD.percent_change_7d           0
# quote.USD.percent_change_30d          0
# quote.USD.percent_change_60d          0
# quote.USD.percent_change_90d          0
# quote.USD.market_cap                  0
# quote.USD.market_cap_dominance        0
# quote.USD.fully_diluted_market_cap    0
# quote.USD.tvl                         5
# quote.USD.last_updated                0
# platform.id                           3
# platform.name                         3
# platform.symbol                       3
# platform.slug                         3
# platform.token_address                3
# dtype: int64

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['timestamp'] = pd.to_datetime('now')

# %% [markdown]
# ***API FUNCTION***

# %%
base_url = 'https://pro-api.coinmarketcap.com'
url_1 = base_url + '/v1/cryptocurrency/listings/latest'

# %%
def cmc_api(api_key, url):
    # extract data
    from requests import Request, Session
    from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
    import json

    parameters = {
      'start':'1',
      'limit':'5000',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': api_key,
    }

    session = Session()
    session.headers.update(headers)

    try:
        response = session.get(url, params=parameters)
        data = json.loads(response.text)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)
        
    # normalize json file into pd
    df = pd.json_normalize(data['data'])
    
    # put data into df
    df['timestamp'] = pd.to_datetime('now')
    
    # save and append df into csv file
    file_name = url.split('/')[-1]
    
    if not os.path.isfile('API.csv'):
        df.to_csv(f'{file_name}.csv', header='column_names')
    else:
        df.to_csv(f'{file_name}.csv', mode='a', header=False)

    return df

# %%
# latest data i.e url_1
latest = cmc_api(my_api_key, url_1)

# %% [markdown]
# ## EDA

# %%
data = pd.read_csv('latest.csv')

# %%
# rid scientific notation
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'symbol', 'slug', 'num_market_pairs',
#        'date_added', 'tags', 'max_supply', 'circulating_supply',
#        'total_supply', 'platform', 'cmc_rank',
#        'self_reported_circulating_supply', 'self_reported_market_cap',
#        'tvl_ratio', 'last_updated', 'quote.USD.price', 'quote.USD.volume_24h',
#        'quote.USD.volume_change_24h', 'quote.USD.percent_change_1h',
#        'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d',
#        'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d',
#        'quote.USD.percent_change_90d', 'quote.USD.market_cap',
#        'quote.USD.market_cap_dominance', 'quote.USD.fully_diluted_market_cap',
#        'quote.USD.tvl', 'quote.USD.last_updated', 'platform.id',
#        'platform.name', 'platform.symbol', 'platform.slug',
#        'platform.token_address', 'timestamp'],
#       dtype='object')

# %%
del data['Unnamed: 0']

# %%
data.isnull().sum()
# Out:
# id                                       0
# name                                     0
# symbol                                   0
# slug                                     0
# num_market_pairs                         0
# date_added                               0
# tags                                     0
# max_supply                            1594
# circulating_supply                       0
# total_supply                             0
# platform                              5000
# cmc_rank                                 0
# self_reported_circulating_supply      3113
# self_reported_market_cap              3113
# tvl_ratio                             4898
# last_updated                             0
# quote.USD.price                          0
# quote.USD.volume_24h                     0
# quote.USD.volume_change_24h              0
# quote.USD.percent_change_1h              0
# quote.USD.percent_change_24h             0
# quote.USD.percent_change_7d              0
# quote.USD.percent_change_30d             0
# quote.USD.percent_change_60d             0
# quote.USD.percent_change_90d             0
# quote.USD.market_cap                     0
# quote.USD.market_cap_dominance           0
# quote.USD.fully_diluted_market_cap       0
# quote.USD.tvl                         4891
# quote.USD.last_updated                   0
# platform.id                            997
# platform.name                          997
# platform.symbol                        997
# platform.slug                          997
# platform.token_address                 997
# timestamp                                0
# dtype: int64

# %% [markdown]
# ### A) Look at percentage change of top 5 coins by market cap

# %%
df_changes = data[['name', 'quote.USD.market_cap','quote.USD.volume_24h',
       'quote.USD.volume_change_24h', 'quote.USD.percent_change_1h',
       'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d',
       'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d',
       'quote.USD.percent_change_90d']]

# %%
top_5_changes = df_changes.sort_values('quote.USD.market_cap', ascending=False).head()
top_5_changes = top_5_changes.set_index('name')
top_5_changes
# Out:
#           quote.USD.market_cap  quote.USD.volume_24h  \
# name
# Bitcoin     443247665029.83008     16091518062.98858
# Ethereum    208983878862.67236     12137714147.10661
# Tether       66483344725.91978     32922659269.40826
# USD Coin     54290914526.27281      4043333968.31752
# BNB          51476869761.36022      1114467453.35139
#
#           quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# name
# Bitcoin                     -43.90040                      0.18841
# Ethereum                    -31.86680                      0.29931
# Tether                      -32.97220                      0.00173
# USD Coin                    -34.66100                      0.00852
# BNB                         -31.39910                      0.19813
#
#           quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# name
# Bitcoin                        0.35895                     -3.17141
# Ethereum                       1.13735                      0.57737
# Tether                         0.00050                     -0.01392
# USD Coin                       0.00146                      0.02557
# BNB                            1.14306                     10.10268
#
#           quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# name
# Bitcoin                        7.33166                     -26.13463
# Ethereum                      38.72030                      -6.84146
# Tether                         0.06594                       0.07150
# USD Coin                      -0.00299                      -0.01016
# BNB                           31.71614                       9.56194
#
#           quote.USD.percent_change_90d
# name
# Bitcoin                      -32.64213
# Ethereum                     -32.87427
# Tether                         0.02294
# USD Coin                      -0.03542
# BNB                          -11.18906

# %%
top_5_changes = top_5_changes.iloc[:, 3:]
top_5_changes
# Out:
#           quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                       0.18841                       0.35895
# Ethereum                      0.29931                       1.13735
# Tether                        0.00173                       0.00050
# USD Coin                      0.00852                       0.00146
# BNB                           0.19813                       1.14306
#
#           quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                      -3.17141                       7.33166
# Ethereum                      0.57737                      38.72030
# Tether                       -0.01392                       0.06594
# USD Coin                      0.02557                      -0.00299
# BNB                          10.10268                      31.71614
#
#           quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                      -26.13463                     -32.64213
# Ethereum                      -6.84146                     -32.87427
# Tether                         0.07150                       0.02294
# USD Coin                      -0.01016                      -0.03542
# BNB                            9.56194                     -11.18906

# %%
stacked_df = top_5_changes.stack().to_frame(name='values')
stacked_df = stacked_df.reset_index()
stacked_df
# Out:
#         name                       level_1    values
# 0    Bitcoin   quote.USD.percent_change_1h   0.18841
# 1    Bitcoin  quote.USD.percent_change_24h   0.35895
# 2    Bitcoin   quote.USD.percent_change_7d  -3.17141
# 3    Bitcoin  quote.USD.percent_change_30d   7.33166
# 4    Bitcoin  quote.USD.percent_change_60d -26.13463
# 5    Bitcoin  quote.USD.percent_change_90d -32.64213
# 6   Ethereum   quote.USD.percent_change_1h   0.29931
# 7   Ethereum  quote.USD.percent_change_24h   1.13735
# 8   Ethereum   quote.USD.percent_change_7d   0.57737
# 9   Ethereum  quote.USD.percent_change_30d  38.72030
# 10  Ethereum  quote.USD.percent_change_60d  -6.84146
# 11  Ethereum  quote.USD.percent_change_90d -32.87427
# 12    Tether   quote.USD.percent_change_1h   0.00173
# 13    Tether  quote.USD.percent_change_24h   0.00050
# 14    Tether   quote.USD.percent_change_7d  -0.01392
# 15    Tether  quote.USD.percent_change_30d   0.06594
# 16    Tether  quote.USD.percent_change_60d   0.07150
# 17    Tether  quote.USD.percent_change_90d   0.02294
# 18  USD Coin   quote.USD.percent_change_1h   0.00852
# 19  USD Coin  quote.USD.percent_change_24h   0.00146
# 20  USD Coin   quote.USD.percent_change_7d   0.02557
# 21  USD Coin  quote.USD.percent_change_30d  -0.00299
# 22  USD Coin  quote.USD.percent_change_60d  -0.01016
# 23  USD Coin  quote.USD.percent_change_90d  -0.03542
# 24       BNB   quote.USD.percent_change_1h   0.19813
# 25       BNB  quote.USD.percent_change_24h   1.14306
# 26       BNB   quote.USD.percent_change_7d  10.10268
# 27       BNB  quote.USD.percent_change_30d  31.71614
# 28       BNB  quote.USD.percent_change_60d   9.56194
# 29       BNB  quote.USD.percent_change_90d -11.18906

# %%
stacked_df = stacked_df.rename(columns={'level_1':'Time Frame', 'values':'Percentage Change'})

# %%
stacked_df['Time Frame'] = stacked_df['Time Frame'].str.replace('quote.USD.percent_change_', '', regex=False)

# %%
stacked_df
# Out:
#         name Time Frame  Percentage Change
# 0    Bitcoin         1h            0.18841
# 1    Bitcoin        24h            0.35895
# 2    Bitcoin         7d           -3.17141
# 3    Bitcoin        30d            7.33166
# 4    Bitcoin        60d          -26.13463
# 5    Bitcoin        90d          -32.64213
# 6   Ethereum         1h            0.29931
# 7   Ethereum        24h            1.13735
# 8   Ethereum         7d            0.57737
# 9   Ethereum        30d           38.72030
# 10  Ethereum        60d           -6.84146
# 11  Ethereum        90d          -32.87427
# 12    Tether         1h            0.00173
# 13    Tether        24h            0.00050
# 14    Tether         7d           -0.01392
# 15    Tether        30d            0.06594
# 16    Tether        60d            0.07150
# 17    Tether        90d            0.02294
# 18  USD Coin         1h            0.00852
# 19  USD Coin        24h            0.00146
# 20  USD Coin         7d            0.02557
# 21  USD Coin        30d           -0.00299
# 22  USD Coin        60d           -0.01016
# 23  USD Coin        90d           -0.03542
# 24       BNB         1h            0.19813
# 25       BNB        24h            1.14306
# 26       BNB         7d           10.10268
# 27       BNB        30d           31.71614
# 28       BNB        60d            9.56194
# 29       BNB        90d          -11.18906

# %%
sns.catplot(x='Time Frame', y='Percentage Change', hue='name', data=stacked_df, kind='point', height=7, aspect=1.5)
plt.show()

# %% [markdown]
# ### B) Which top 100 coins have been performing the best in the past 90 days?

# %%
best_pc_change = df_changes.iloc[:100, :].sort_values('quote.USD.percent_change_90d', ascending=False).head(10)
best_pc_change.set_index('name', inplace=True)
best_pc_change = best_pc_change.iloc[:, 4:]
best_pc_change
# Out:
#                     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# name
# Quant                                   14.69925                     17.38220
# Ethereum Classic                         2.51799                     -4.09940
# Trust Wallet Token                      -1.89198                     22.98609
# Uniswap                                 -1.60810                      1.77412
# OKB                                      1.09199                      0.70117
# Bitcoin Gold                             0.37718                    -14.87910
# Fei USD                                  0.21022                      0.69644
# Neutrino USD                            -0.56394                     -0.35336
# Binance USD                             -0.01460                     -0.06851
# Tether                                   0.00050                     -0.01392
#
#                     quote.USD.percent_change_30d  \
# name
# Quant                                   94.56937
# Ethereum Classic                       140.82646
# Trust Wallet Token                      43.78113
# Uniswap                                 56.37438
# OKB                                     42.79088
# Bitcoin Gold                            76.78402
# Fei USD                                 -0.16871
# Neutrino USD                            -0.26473
# Binance USD                              0.04067
# Tether                                   0.06594
#
#                     quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Quant                                   87.39099                      46.59677
# Ethereum Classic                        73.80018                      40.41029
# Trust Wallet Token                      89.31625                      36.69737
# Uniswap                                 67.25690                      22.36135
# OKB                                     60.23797                      14.24951
# Bitcoin Gold                            32.18767                      11.33370
# Fei USD                                  0.03740                       0.76989
# Neutrino USD                            -0.85866                       0.44957
# Binance USD                             -0.16247                       0.08372
# Tether                                   0.07150                       0.02294

# %%
best_pc_change = best_pc_change.stack().to_frame(name='values')
best_pc_change = best_pc_change.reset_index()
best_pc_change = best_pc_change.rename(columns={'level_1':'Time Frame', 'values':'Percentage Change'})
best_pc_change['Time Frame'] = best_pc_change['Time Frame'].str.replace('quote.USD.percent_change_', '', regex=False)
best_pc_change
# Out:
#                   name Time Frame  Percentage Change
# 0                Quant        24h           14.69925
# 1                Quant         7d           17.38220
# 2                Quant        30d           94.56937
# 3                Quant        60d           87.39099
# 4                Quant        90d           46.59677
# 5     Ethereum Classic        24h            2.51799
# 6     Ethereum Classic         7d           -4.09940
# 7     Ethereum Classic        30d          140.82646
# 8     Ethereum Classic        60d           73.80018
# 9     Ethereum Classic        90d           40.41029
# 10  Trust Wallet Token        24h           -1.89198
# 11  Trust Wallet Token         7d           22.98609
# 12  Trust Wallet Token        30d           43.78113
# 13  Trust Wallet Token        60d           89.31625
# 14  Trust Wallet Token        90d           36.69737
# 15             Uniswap        24h           -1.60810
# 16             Uniswap         7d            1.77412
# 17             Uniswap        30d           56.37438
# 18             Uniswap        60d           67.25690
# 19             Uniswap        90d           22.36135
# 20                 OKB        24h            1.09199
# 21                 OKB         7d            0.70117
# 22                 OKB        30d           42.79088
# 23                 OKB        60d           60.23797
# 24                 OKB        90d           14.24951
# 25        Bitcoin Gold        24h            0.37718
# 26        Bitcoin Gold         7d          -14.87910
# 27        Bitcoin Gold        30d           76.78402
# 28        Bitcoin Gold        60d           32.18767
# 29        Bitcoin Gold        90d           11.33370
# 30             Fei USD        24h            0.21022
# 31             Fei USD         7d            0.69644
# 32             Fei USD        30d           -0.16871
# 33             Fei USD        60d            0.03740
# 34             Fei USD        90d            0.76989
# 35        Neutrino USD        24h           -0.56394
# 36        Neutrino USD         7d           -0.35336
# 37        Neutrino USD        30d           -0.26473
# 38        Neutrino USD        60d           -0.85866
# 39        Neutrino USD        90d            0.44957
# 40         Binance USD        24h           -0.01460
# 41         Binance USD         7d           -0.06851
# 42         Binance USD        30d            0.04067
# 43         Binance USD        60d           -0.16247
# 44         Binance USD        90d            0.08372
# 45              Tether        24h            0.00050
# 46              Tether         7d           -0.01392
# 47              Tether        30d            0.06594
# 48              Tether        60d            0.07150
# 49              Tether        90d            0.02294

# %%
sns.catplot(x='Time Frame', y='Percentage Change', hue='name', data=best_pc_change, kind='point', height=7, aspect=1.5)
plt.show()

# %% [markdown]
# ### C) Best performing and worst performing coins in the 50mil to 1bil market cap range

# %%
potentials = df_changes[(df_changes['quote.USD.market_cap'] >= 500000000) & (df_changes['quote.USD.market_cap'] <=1000000000)]
potentials
# Out:
#                       name  quote.USD.market_cap  quote.USD.volume_24h  \
# 52                    IOTA       956133336.92007        11180973.69301
# 53              Pax Dollar       945681005.44819         3353460.92063
# 54                  Fantom       945598198.56553       264691394.55859
# 55          BitTorrent-New       917816076.10555        25157064.43489
# 56               THORChain       896679026.81366        72651297.54539
# 57               The Graph       894705484.54083        51886867.47196
# 58                  Chiliz       887835404.82179       112360332.73207
# 59                  Klaytn       878612061.48586        34220723.35031
# 60                   eCash       867501367.78223        12069728.40357
# 61                Lido DAO       827580410.91969        98029870.95872
# 62                     Neo       814583652.95433        42829583.80288
# 63                    USDD       745397471.31689        38410848.28353
# 64         Curve DAO Token       731811473.34709       138282968.26049
# 65            Neutrino USD       711031625.88102         5115706.84486
# 66             Huobi Token       673430842.75484         8561284.92850
# 67                   Waves       671204560.62014       233410080.90308
# 68   Basic Attention Token       653997199.98049        85475825.98801
# 69                  Stacks       650548804.06501         9621243.84552
# 70              Enjin Coin       615330534.89142        63858293.27320
# 71                 Zilliqa       608474852.79446       301189282.22310
# 72             PancakeSwap       605525077.78263        39058248.02934
# 73                PAX Gold       601371922.41876         6793831.03096
# 74                Loopring       586729492.14924        65309567.43054
# 75                    Dash       578710453.78446        83089959.31513
# 76                  Decred       578032053.48324       139692020.77248
# 77                  Kusama       571016946.12483        42729835.38521
# 78                   STEPN       562304981.67255       182993193.68782
# 79                    Kava       531850792.71492        34219831.63573
# 80                    Mina       531470067.39172        34682472.42460
# 81            Bitcoin Gold       512779099.00394        16157691.32549
# 82                 Arweave       500842514.34456        38235903.68380
# 211              Huobi BTC       903925384.82633           56041.23029
# 212          Terra Classic       661492905.10213        36083572.31446
#
#      quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 52                     -27.61190                      0.30334
# 53                     -22.34120                      0.00604
# 54                     -29.03550                      0.63793
# 55                     -23.91970                      0.09050
# 56                     -38.40540                      0.28466
# 57                     -39.48750                      0.44822
# 58                     -26.43550                      0.41684
# 59                     -25.41970                     -0.21271
# 60                      13.47200                      0.07461
# 61                     -33.61720                      1.65479
# 62                     -52.00480                      0.15835
# 63                       3.15990                      0.02513
# 64                     -34.63390                      0.42799
# 65                      21.86940                      0.03863
# 66                     -20.89370                      0.05470
# 67                     -66.21230                      0.42141
# 68                     -25.71750                      0.38844
# 69                     -45.28850                      0.06469
# 70                     -42.29170                      0.19101
# 71                      42.70520                      0.10733
# 72                     -55.28010                      0.04817
# 73                     -58.30820                      0.04747
# 74                     -24.53930                      0.42278
# 75                     -17.33620                      0.45011
# 76                      60.89800                      0.01226
# 77                      18.63810                      0.98551
# 78                     -18.52330                      0.48013
# 79                     -18.07140                      0.25656
# 80                      53.43010                      0.10873
# 81                     -34.07380                      0.50587
# 82                       7.67710                      0.44540
# 211                    -77.11410                      0.17540
# 212                     -0.92640                      0.16013
#
#      quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 52                        2.48265                      6.14766
# 53                       -0.05330                     -0.01400
# 54                       -1.12520                      8.76262
# 55                        0.56395                      2.48719
# 56                       -0.21266                     -0.02200
# 57                        1.28039                     -3.91697
# 58                        2.59823                     14.95596
# 59                        0.34463                     -6.35142
# 60                        0.77702                      0.83882
# 61                        3.59925                     11.35738
# 62                       -1.38846                     -0.25943
# 63                        0.01221                      0.12552
# 64                       -0.99244                      0.57278
# 65                       -0.56394                     -0.35336
# 66                       -1.04690                     -3.22043
# 67                        0.14356                      7.38462
# 68                        2.84000                      5.85788
# 69                        1.04738                     11.26701
# 70                       -1.35811                      7.93571
# 71                        4.66518                      8.61381
# 72                        1.47950                      6.03909
# 73                        0.05162                      0.29838
# 74                        2.64248                      0.20984
# 75                        3.48693                      3.59826
# 76                      -30.49753                     44.72576
# 77                        7.70753                      4.98787
# 78                        0.72279                     -6.47105
# 79                        0.56240                     13.13807
# 80                        3.26037                      5.30215
# 81                        0.37718                    -14.87910
# 82                        2.77396                      0.17655
# 211                       0.28982                     -3.14130
# 212                       0.22485                      1.86964
#
#      quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 52                       20.27021                      -3.24586
# 53                        0.05185                      -0.02331
# 54                       35.27589                       4.37597
# 55                        6.00528                     -10.63757
# 56                       13.94962                      -9.55260
# 57                       27.02985                     -16.89653
# 58                       45.03553                      18.35934
# 59                       22.48390                     -25.30126
# 60                        4.75002                     -20.58093
# 61                      285.76145                     147.67849
# 62                       25.86371                      -3.61423
# 63                        0.80003                      -0.00583
# 64                       35.59428                      14.48836
# 65                       -0.26473                      -0.85866
# 66                       -6.92665                     -40.40975
# 67                        9.41655                     -23.13023
# 68                       -2.81753                      10.35374
# 69                       19.19395                     -10.41413
# 70                       24.32372                       7.24930
# 71                       13.01054                      -8.35552
# 72                       27.90063                      -6.71484
# 73                        1.62865                      -4.58759
# 74                        5.98810                     -18.78822
# 75                       16.23164                     -11.61382
# 76                       72.50122                      10.23910
# 77                       28.10316                      -2.83064
# 78                       -8.30545                      -4.48510
# 79                       16.29376                     -17.41496
# 80                       21.82147                      -2.12405
# 81                       76.78402                      32.18767
# 82                       24.77856                       8.44712
# 211                       7.29431                     -26.04596
# 212                     -11.22926                      42.19161
#
#      quote.USD.percent_change_90d
# 52                      -27.51353
# 53                       -0.41133
# 54                      -46.82993
# 55                      -39.07965
# 56                      -54.08061
# 57                      -57.67911
# 58                      -10.35415
# 59                      -52.11379
# 60                      -34.89771
# 61                       -7.80637
# 62                      -28.54129
# 63                       -0.21318
# 64                      -41.86981
# 65                        0.44957
# 66                      -50.12891
# 67                      -53.22102
# 68                      -21.34461
# 69                      -37.90888
# 70                      -29.71966
# 71                      -41.23093
# 72                      -40.17099
# 73                       -6.15137
# 74                      -34.78070
# 75                      -36.61532
# 76                      -18.82288
# 77                      -40.77235
# 78                      -64.73528
# 79                      -37.44667
# 80                      -48.66225
# 81                       11.33370
# 82                      -26.41167
# 211                     -32.54666
# 212                     -99.99985

# %% [markdown]
# - potentials_1 = top 10 best performing
# - potentials_2 = top 10 worst performing

# %%
potentials_1 = potentials.sort_values('quote.USD.percent_change_90d', ascending=False).head(10)
potentials_1.set_index('name', inplace=True)
potentials_1 = potentials_1.iloc[:, 4:]
potentials_1
# Out:
#                        quote.USD.percent_change_24h  \
# name
# Bitcoin Gold                                0.37718
# Neutrino USD                               -0.56394
# USDD                                        0.01221
# Pax Dollar                                 -0.05330
# PAX Gold                                    0.05162
# Lido DAO                                    3.59925
# Chiliz                                      2.59823
# Decred                                    -30.49753
# Basic Attention Token                       2.84000
# Arweave                                     2.77396
#
#                        quote.USD.percent_change_7d  \
# name
# Bitcoin Gold                             -14.87910
# Neutrino USD                              -0.35336
# USDD                                       0.12552
# Pax Dollar                                -0.01400
# PAX Gold                                   0.29838
# Lido DAO                                  11.35738
# Chiliz                                    14.95596
# Decred                                    44.72576
# Basic Attention Token                      5.85788
# Arweave                                    0.17655
#
#                        quote.USD.percent_change_30d  \
# name
# Bitcoin Gold                               76.78402
# Neutrino USD                               -0.26473
# USDD                                        0.80003
# Pax Dollar                                  0.05185
# PAX Gold                                    1.62865
# Lido DAO                                  285.76145
# Chiliz                                     45.03553
# Decred                                     72.50122
# Basic Attention Token                      -2.81753
# Arweave                                    24.77856
#
#                        quote.USD.percent_change_60d  \
# name
# Bitcoin Gold                               32.18767
# Neutrino USD                               -0.85866
# USDD                                       -0.00583
# Pax Dollar                                 -0.02331
# PAX Gold                                   -4.58759
# Lido DAO                                  147.67849
# Chiliz                                     18.35934
# Decred                                     10.23910
# Basic Attention Token                      10.35374
# Arweave                                     8.44712
#
#                        quote.USD.percent_change_90d
# name
# Bitcoin Gold                               11.33370
# Neutrino USD                                0.44957
# USDD                                       -0.21318
# Pax Dollar                                 -0.41133
# PAX Gold                                   -6.15137
# Lido DAO                                   -7.80637
# Chiliz                                    -10.35415
# Decred                                    -18.82288
# Basic Attention Token                     -21.34461
# Arweave                                   -26.41167

# %%
potentials_2 = potentials.sort_values('quote.USD.percent_change_90d', ascending=True).head(10)
potentials_2.set_index('name', inplace=True)
potentials_2 = potentials_2.iloc[:, 4:]
potentials_2
# Out:
#                  quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# name
# Terra Classic                         0.22485                      1.86964
# STEPN                                 0.72279                     -6.47105
# The Graph                             1.28039                     -3.91697
# THORChain                            -0.21266                     -0.02200
# Waves                                 0.14356                      7.38462
# Klaytn                                0.34463                     -6.35142
# Huobi Token                          -1.04690                     -3.22043
# Mina                                  3.26037                      5.30215
# Fantom                               -1.12520                      8.76262
# Curve DAO Token                      -0.99244                      0.57278
#
#                  quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# name
# Terra Classic                       -11.22926                      42.19161
# STEPN                                -8.30545                      -4.48510
# The Graph                            27.02985                     -16.89653
# THORChain                            13.94962                      -9.55260
# Waves                                 9.41655                     -23.13023
# Klaytn                               22.48390                     -25.30126
# Huobi Token                          -6.92665                     -40.40975
# Mina                                 21.82147                      -2.12405
# Fantom                               35.27589                       4.37597
# Curve DAO Token                      35.59428                      14.48836
#
#                  quote.USD.percent_change_90d
# name
# Terra Classic                       -99.99985
# STEPN                               -64.73528
# The Graph                           -57.67911
# THORChain                           -54.08061
# Waves                               -53.22102
# Klaytn                              -52.11379
# Huobi Token                         -50.12891
# Mina                                -48.66225
# Fantom                              -46.82993
# Curve DAO Token                     -41.86981

# %%
potentials_1 = potentials_1.stack().to_frame(name='values')
potentials_1 = potentials_1.reset_index()
potentials_1 = potentials_1.rename(columns={'level_1':'Time Frame', 'values':'Percentage Change'})
potentials_1['Time Frame'] = potentials_1['Time Frame'].str.replace('quote.USD.percent_change_', '', regex=False)
potentials_1
# Out:
#                      name Time Frame  Percentage Change
# 0            Bitcoin Gold        24h            0.37718
# 1            Bitcoin Gold         7d          -14.87910
# 2            Bitcoin Gold        30d           76.78402
# 3            Bitcoin Gold        60d           32.18767
# 4            Bitcoin Gold        90d           11.33370
# 5            Neutrino USD        24h           -0.56394
# 6            Neutrino USD         7d           -0.35336
# 7            Neutrino USD        30d           -0.26473
# 8            Neutrino USD        60d           -0.85866
# 9            Neutrino USD        90d            0.44957
# 10                   USDD        24h            0.01221
# 11                   USDD         7d            0.12552
# 12                   USDD        30d            0.80003
# 13                   USDD        60d           -0.00583
# 14                   USDD        90d           -0.21318
# 15             Pax Dollar        24h           -0.05330
# 16             Pax Dollar         7d           -0.01400
# 17             Pax Dollar        30d            0.05185
# 18             Pax Dollar        60d           -0.02331
# 19             Pax Dollar        90d           -0.41133
# 20               PAX Gold        24h            0.05162
# 21               PAX Gold         7d            0.29838
# 22               PAX Gold        30d            1.62865
# 23               PAX Gold        60d           -4.58759
# 24               PAX Gold        90d           -6.15137
# 25               Lido DAO        24h            3.59925
# 26               Lido DAO         7d           11.35738
# 27               Lido DAO        30d          285.76145
# 28               Lido DAO        60d          147.67849
# 29               Lido DAO        90d           -7.80637
# 30                 Chiliz        24h            2.59823
# 31                 Chiliz         7d           14.95596
# 32                 Chiliz        30d           45.03553
# 33                 Chiliz        60d           18.35934
# 34                 Chiliz        90d          -10.35415
# 35                 Decred        24h          -30.49753
# 36                 Decred         7d           44.72576
# 37                 Decred        30d           72.50122
# 38                 Decred        60d           10.23910
# 39                 Decred        90d          -18.82288
# 40  Basic Attention Token        24h            2.84000
# 41  Basic Attention Token         7d            5.85788
# 42  Basic Attention Token        30d           -2.81753
# 43  Basic Attention Token        60d           10.35374
# 44  Basic Attention Token        90d          -21.34461
# 45                Arweave        24h            2.77396
# 46                Arweave         7d            0.17655
# 47                Arweave        30d           24.77856
# 48                Arweave        60d            8.44712
# 49                Arweave        90d          -26.41167

# %%
potentials_2 = potentials_2.stack().to_frame(name='values')
potentials_2 = potentials_2.reset_index()
potentials_2 = potentials_2.rename(columns={'level_1':'Time Frame', 'values':'Percentage Change'})
potentials_2['Time Frame'] = potentials_2['Time Frame'].str.replace('quote.USD.percent_change_', '', regex=False)
potentials_2
# Out:
#                name Time Frame  Percentage Change
# 0     Terra Classic        24h            0.22485
# 1     Terra Classic         7d            1.86964
# 2     Terra Classic        30d          -11.22926
# 3     Terra Classic        60d           42.19161
# 4     Terra Classic        90d          -99.99985
# 5             STEPN        24h            0.72279
# 6             STEPN         7d           -6.47105
# 7             STEPN        30d           -8.30545
# 8             STEPN        60d           -4.48510
# 9             STEPN        90d          -64.73528
# 10        The Graph        24h            1.28039
# 11        The Graph         7d           -3.91697
# 12        The Graph        30d           27.02985
# 13        The Graph        60d          -16.89653
# 14        The Graph        90d          -57.67911
# 15        THORChain        24h           -0.21266
# 16        THORChain         7d           -0.02200
# 17        THORChain        30d           13.94962
# 18        THORChain        60d           -9.55260
# 19        THORChain        90d          -54.08061
# 20            Waves        24h            0.14356
# 21            Waves         7d            7.38462
# 22            Waves        30d            9.41655
# 23            Waves        60d          -23.13023
# 24            Waves        90d          -53.22102
# 25           Klaytn        24h            0.34463
# 26           Klaytn         7d           -6.35142
# 27           Klaytn        30d           22.48390
# 28           Klaytn        60d          -25.30126
# 29           Klaytn        90d          -52.11379
# 30      Huobi Token        24h           -1.04690
# 31      Huobi Token         7d           -3.22043
# 32      Huobi Token        30d           -6.92665
# 33      Huobi Token        60d          -40.40975
# 34      Huobi Token        90d          -50.12891
# 35             Mina        24h            3.26037
# 36             Mina         7d            5.30215
# 37             Mina        30d           21.82147
# 38             Mina        60d           -2.12405
# 39             Mina        90d          -48.66225
# 40           Fantom        24h           -1.12520
# 41           Fantom         7d            8.76262
# 42           Fantom        30d           35.27589
# 43           Fantom        60d            4.37597
# 44           Fantom        90d          -46.82993
# 45  Curve DAO Token        24h           -0.99244
# 46  Curve DAO Token         7d            0.57278
# 47  Curve DAO Token        30d           35.59428
# 48  Curve DAO Token        60d           14.48836
# 49  Curve DAO Token        90d          -41.86981

# %%
sns.catplot(x='Time Frame', y='Percentage Change', hue='name', data=potentials_1, kind='point', height=7, aspect=1.5)
plt.show()

# %%
sns.catplot(x='Time Frame', y='Percentage Change', hue='name', data=potentials_2, kind='point', height=7, aspect=1.5)
plt.show()

# %% [markdown]
# **END**
